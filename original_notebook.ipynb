# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Task-statistics" data-toc-modified-id="Task-statistics-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Task statistics</a></span></li><li><span><a href="#Train-model" data-toc-modified-id="Train-model-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Train model</a></span><ul class="toc-item"><li><span><a href="#Evaluate-performance" data-toc-modified-id="Evaluate-performance-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Evaluate performance</a></span></li></ul></li><li><span><a href="#Ratemaps" data-toc-modified-id="Ratemaps-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Ratemaps</a></span><ul class="toc-item"><li><span><a href="#Grid-scores" data-toc-modified-id="Grid-scores-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Grid scores</a></span></li></ul></li><li><span><a href="#Manifold-distance" data-toc-modified-id="Manifold-distance-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Manifold distance</a></span></li><li><span><a href="#Neural-sheet" data-toc-modified-id="Neural-sheet-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Neural sheet</a></span></li><li><span><a href="#Connectivity" data-toc-modified-id="Connectivity-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Connectivity</a></span><ul class="toc-item"><li><span><a href="#Sort-weights" data-toc-modified-id="Sort-weights-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Sort weights</a></span></li></ul></li><li><span><a href="#Path-integration" data-toc-modified-id="Path-integration-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Path integration</a></span></li><li><span><a href="#SVD" data-toc-modified-id="SVD-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>SVD</a></span></li><li><span><a href="#Null-model-(low-pass-filtered-noise)" data-toc-modified-id="Null-model-(low-pass-filtered-noise)-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Null model (low-pass filtered noise)</a></span></li><li><span><a href="#Boundary-extension" data-toc-modified-id="Boundary-extension-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Boundary extension</a></span></li><li><span><a href="#Head-direction-and-speed-tuning" data-toc-modified-id="Head-direction-and-speed-tuning-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Head direction and speed tuning</a></span></li><li><span><a href="#Border-score" data-toc-modified-id="Border-score-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Border score</a></span></li></ul></div>

# %%
import numpy as np
import torch

from tqdm import tqdm
from matplotlib import pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
# If GPUs available, select which to train on
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
from utils import generate_run_ID, load_trained_weights
from place_cells import PlaceCells
from trajectory_generator import TrajectoryGenerator
from model import RNN
from trainer import Trainer

# %%
# Training options and hyperparameters
class Options:
    pass
options = Options()

options.save_dir = 'experiments'
options.n_steps = 100 # 100_000     # number of training steps
options.batch_size = 5_000 # 200     # number of trajectories per batch
options.sequence_length = 20  # number of steps in trajectory
options.learning_rate = 1e-4  # gradient descent learning rate
options.Np = 512              # number of place cells
options.Ng = 4096             # number of grid cells
options.place_cell_rf = 0.12*(0.635/2.2) # 0.12  # width of place cell center tuning curve (m)
options.surround_scale = 2    # if DoG, ratio of sigma2^2 to sigma1^2
options.RNN_type = 'RNN'      # RNN or LSTM
options.activation = 'relu'   # recurrent nonlinearity
options.weight_decay = 1e-4   # strength of weight decay on recurrent weights
options.DoG = True            # use difference of gaussians tuning curves
options.periodic = False      # trajectories with periodic boundary conditions
options.box_width = 0.635 # 2.2       # width of training environment
options.box_height = options.box_width      # height of training environment

# additional options which were not given, but necessary
options.device = 'cuda' if torch.cuda.is_available() else 'cpu'

options.run_ID = generate_run_ID(options)

# %%
print("original total number of datapoints")
print(f"{100_000 * 200 * options.sequence_length * 1_000:,f}") # where 1_000 is the number of epochs
# Out:
# original total number of datapoints
# 400,000,000,000.000000

# %%
print("current total number of datapoints (w/ similar results)")
print(f"{options.n_steps * options.batch_size * options.sequence_length * 100:,f}") # where 100 is the number of epochs
# Out:
# current total number of datapoints (w/ similar results)
# 1,000,000,000.000000

# %%
# If you've trained with these params before, will restore trained model
place_cells = PlaceCells(options)
model = RNN(options, place_cells).cuda()
trajectory_generator = TrajectoryGenerator(options, place_cells)
trainer = Trainer(options, model, trajectory_generator)

# # Load example weights stored on github
# weight_dir = options.save_dir + '/example_trained_weights.npy'
# load_trained_weights(model, trainer, weight_dir)
# Out:
# Initializing new model from scratch.
# Saving to: experiments/steps_20_batch_5000_RNN_4096_relu_rf_003463636363636363_DoG_True_periodic_False_lr_00001_weight_decay_00001

# %% [markdown]
# # Task statistics

# %%
# Plot a few sample trajectories
inputs, pos, pc_outputs = trajectory_generator.get_test_batch()
us = place_cells.us.cpu()
pos = pos.cpu()

plt.figure(figsize=(5,5))
plt.scatter(us[:,0], us[:,1], c='lightgrey', label='Place cell centers')
for i in range(5):
    plt.plot(pos[:,i,0],pos[:,i,1], label='Simulated trajectory', c='C1')
    if i==0:
        plt.legend();

# %%
# Plot a few place cell outputs
pc_outputs = pc_outputs.reshape(-1, options.Np).detach().cpu()
pc = place_cells.grid_pc(pc_outputs[::100], res=100)

plt.figure(figsize=(16,2))
for i in range(8):
    plt.subplot(1,8,i+1)
    plt.imshow(pc[i], cmap='jet')
    plt.axis('off')
        
plt.suptitle('Place cell outputs', fontsize=16)
plt.show()

# plt.tight_layout()

# %%
# Visualize place cell covariance matrix
Cmean = place_cells.compute_covariance(res=30)

# Fourier transform
Ctilde = np.fft.fft2(Cmean)
Ctilde[0,0] = 0

plt.figure(figsize=(8,4))
plt.subplot(121)
plt.imshow(Cmean, cmap='jet', interpolation='gaussian')
plt.axis('off')
plt.title(r'$\Sigma$', fontsize=20)

plt.subplot(122)
width = 6
idxs = np.arange(-width+1, width)
x2, y2 = np.meshgrid(np.arange(2*width-1), np.arange(2*width-1))
plt.scatter(x2,y2,c=np.abs(Ctilde)[idxs][:,idxs],
            s=600, cmap='Oranges', marker='s')

plt.axis('equal')
plt.axis('off')
plt.title(r'$\tilde \Sigma$', fontsize=20)
plt.axis('off');

# %% [markdown]
# # Train model

# %%
trainer.train(n_epochs=100, n_steps=options.n_steps, save=True)

plt.figure(figsize=(12,3))
plt.subplot(121)
plt.plot(trainer.err, c='black')

plt.title('Decoding error (m)'); plt.xlabel('train step')
plt.subplot(122)
plt.plot(trainer.loss, c='black');
plt.title('Loss'); plt.xlabel('train step');
# Out:
# Epoch: 1/100. Step 0/100. Loss: 6.37. Err: 28.66cm
# Epoch: 1/100. Step 1/100. Loss: 6.37. Err: 28.8cm
# Epoch: 1/100. Step 2/100. Loss: 6.37. Err: 28.57cm
# Epoch: 1/100. Step 3/100. Loss: 6.37. Err: 28.48cm
# Epoch: 1/100. Step 4/100. Loss: 6.36. Err: 28.45cm
# Epoch: 1/100. Step 5/100. Loss: 6.36. Err: 28.23cm
# Epoch: 1/100. Step 6/100. Loss: 6.36. Err: 27.94cm
# Epoch: 1/100. Step 7/100. Loss: 6.36. Err: 27.65cm
# Epoch: 1/100. Step 8/100. Loss: 6.36. Err: 27.69cm
# Epoch: 1/100. Step 9/100. Loss: 6.35. Err: 27.56cm
# Epoch: 1/100. Step 10/100. Loss: 6.35. Err: 27.37cm
# Epoch: 1/100. Step 11/100. Loss: 6.35. Err: 27.62cm
# Epoch: 1/100. Step 12/100. Loss: 6.35. Err: 27.59cm
# Epoch: 1/100. Step 13/100. Loss: 6.34. Err: 27.35cm
# Epoch: 1/100. Step 14/100. Loss: 6.34. Err: 27.52cm
# Epoch: 1/100. Step 15/100. Loss: 6.34. Err: 27.44cm
# Epoch: 1/100. Step 16/100. Loss: 6.34. Err: 27.28cm
# Epoch: 1/100. Step 17/100. Loss: 6.34. Err: 27.26cm
# Epoch: 1/100. Step 18/100. Loss: 6.33. Err: 27.25cm
# Epoch: 1/100. Step 19/100. Loss: 6.33. Err: 27.2cm
# Epoch: 1/100. Step 20/100. Loss: 6.33. Err: 27.14cm
# Epoch: 1/100. Step 21/100. Loss: 6.33. Err: 27.14cm
# Epoch: 1/100. Step 22/100. Loss: 6.33. Err: 27.16cm
# Epoch: 1/100. Step 23/100. Loss: 6.32. Err: 27.04cm
# Epoch: 1/100. Step 24/100. Loss: 6.32. Err: 27.29cm
# Epoch: 1/100. Step 25/100. Loss: 6.32. Err: 26.96cm
# Epoch: 1/100. Step 26/100. Loss: 6.32. Err: 27.09cm
# Epoch: 1/100. Step 27/100. Loss: 6.32. Err: 27.05cm
# Epoch: 1/100. Step 28/100. Loss: 6.32. Err: 27.03cm
# Epoch: 1/100. Step 29/100. Loss: 6.31. Err: 27.0cm
# Epoch: 1/100. Step 30/100. Loss: 6.31. Err: 26.97cm
# Epoch: 1/100. Step 31/100. Loss: 6.31. Err: 27.08cm
# Epoch: 1/100. Step 32/100. Loss: 6.31. Err: 27.18cm
# Epoch: 1/100. Step 33/100. Loss: 6.31. Err: 27.22cm
# Epoch: 1/100. Step 34/100. Loss: 6.31. Err: 27.01cm
# Epoch: 1/100. Step 35/100. Loss: 6.3. Err: 26.94cm
# Epoch: 1/100. Step 36/100. Loss: 6.3. Err: 27.04cm
# Epoch: 1/100. Step 37/100. Loss: 6.3. Err: 27.15cm
# Epoch: 1/100. Step 38/100. Loss: 6.3. Err: 27.06cm
# Epoch: 1/100. Step 39/100. Loss: 6.3. Err: 27.31cm
# Epoch: 1/100. Step 40/100. Loss: 6.3. Err: 27.19cm
# Epoch: 1/100. Step 41/100. Loss: 6.3. Err: 26.94cm
# Epoch: 1/100. Step 42/100. Loss: 6.29. Err: 27.23cm
# Epoch: 1/100. Step 43/100. Loss: 6.29. Err: 27.09cm
# Epoch: 1/100. Step 44/100. Loss: 6.29. Err: 27.21cm
# Epoch: 1/100. Step 45/100. Loss: 6.29. Err: 27.1cm
# Epoch: 1/100. Step 46/100. Loss: 6.29. Err: 27.19cm
# Epoch: 1/100. Step 47/100. Loss: 6.29. Err: 27.33cm
# Epoch: 1/100. Step 48/100. Loss: 6.29. Err: 27.08cm
# Epoch: 1/100. Step 49/100. Loss: 6.29. Err: 27.39cm
# Epoch: 1/100. Step 50/100. Loss: 6.29. Err: 27.33cm
# Epoch: 1/100. Step 51/100. Loss: 6.28. Err: 27.38cm
# Epoch: 1/100. Step 52/100. Loss: 6.28. Err: 27.46cm
# Epoch: 1/100. Step 53/100. Loss: 6.28. Err: 27.46cm
# Epoch: 1/100. Step 54/100. Loss: 6.28. Err: 27.46cm
# Epoch: 1/100. Step 55/100. Loss: 6.28. Err: 27.17cm
# Epoch: 1/100. Step 56/100. Loss: 6.28. Err: 27.09cm
# Epoch: 1/100. Step 57/100. Loss: 6.28. Err: 27.39cm
# Epoch: 1/100. Step 58/100. Loss: 6.28. Err: 27.31cm
# Epoch: 1/100. Step 59/100. Loss: 6.28. Err: 27.36cm
# Epoch: 1/100. Step 60/100. Loss: 6.28. Err: 27.21cm
# Epoch: 1/100. Step 61/100. Loss: 6.28. Err: 27.18cm
# Epoch: 1/100. Step 62/100. Loss: 6.27. Err: 27.25cm
# Epoch: 1/100. Step 63/100. Loss: 6.27. Err: 27.31cm
# Epoch: 1/100. Step 64/100. Loss: 6.27. Err: 27.38cm
# Epoch: 1/100. Step 65/100. Loss: 6.27. Err: 27.48cm
# Epoch: 1/100. Step 66/100. Loss: 6.27. Err: 27.45cm
# Epoch: 1/100. Step 67/100. Loss: 6.27. Err: 27.15cm
# Epoch: 1/100. Step 68/100. Loss: 6.27. Err: 27.22cm
# Epoch: 1/100. Step 69/100. Loss: 6.27. Err: 27.37cm
# Epoch: 1/100. Step 70/100. Loss: 6.27. Err: 27.47cm
# Epoch: 1/100. Step 71/100. Loss: 6.27. Err: 27.54cm
# Epoch: 1/100. Step 72/100. Loss: 6.27. Err: 27.32cm
# Epoch: 1/100. Step 73/100. Loss: 6.27. Err: 27.53cm
# Epoch: 1/100. Step 74/100. Loss: 6.27. Err: 27.54cm
# Epoch: 1/100. Step 75/100. Loss: 6.26. Err: 27.24cm
# Epoch: 1/100. Step 76/100. Loss: 6.26. Err: 27.63cm
# Epoch: 1/100. Step 77/100. Loss: 6.26. Err: 27.63cm
# Epoch: 1/100. Step 78/100. Loss: 6.26. Err: 27.54cm
# Epoch: 1/100. Step 79/100. Loss: 6.26. Err: 27.19cm
# Epoch: 1/100. Step 80/100. Loss: 6.26. Err: 27.9cm
# Epoch: 1/100. Step 81/100. Loss: 6.26. Err: 27.5cm
# Epoch: 1/100. Step 82/100. Loss: 6.26. Err: 27.65cm
# Epoch: 1/100. Step 83/100. Loss: 6.26. Err: 27.57cm
# Epoch: 1/100. Step 84/100. Loss: 6.26. Err: 27.47cm
# Epoch: 1/100. Step 85/100. Loss: 6.26. Err: 27.67cm
# Epoch: 1/100. Step 86/100. Loss: 6.26. Err: 27.65cm
# Epoch: 1/100. Step 87/100. Loss: 6.26. Err: 27.55cm
# Epoch: 1/100. Step 88/100. Loss: 6.26. Err: 27.79cm
# Epoch: 1/100. Step 89/100. Loss: 6.26. Err: 27.63cm
# Epoch: 1/100. Step 90/100. Loss: 6.26. Err: 27.73cm
# Epoch: 1/100. Step 91/100. Loss: 6.26. Err: 27.72cm
# Epoch: 1/100. Step 92/100. Loss: 6.26. Err: 27.56cm
# Epoch: 1/100. Step 93/100. Loss: 6.26. Err: 27.48cm
# Epoch: 1/100. Step 94/100. Loss: 6.25. Err: 27.63cm
# Epoch: 1/100. Step 95/100. Loss: 6.25. Err: 27.51cm
# Epoch: 1/100. Step 96/100. Loss: 6.25. Err: 27.83cm
# Epoch: 1/100. Step 97/100. Loss: 6.25. Err: 27.66cm
# Epoch: 1/100. Step 98/100. Loss: 6.25. Err: 27.77cm
# Epoch: 1/100. Step 99/100. Loss: 6.25. Err: 27.72cm
# Epoch: 2/100. Step 0/100. Loss: 6.25. Err: 27.64cm
# Epoch: 2/100. Step 1/100. Loss: 6.25. Err: 27.64cm
# Epoch: 2/100. Step 2/100. Loss: 6.25. Err: 27.55cm
# Epoch: 2/100. Step 3/100. Loss: 6.25. Err: 27.72cm
# Epoch: 2/100. Step 4/100. Loss: 6.25. Err: 27.79cm
# Epoch: 2/100. Step 5/100. Loss: 6.25. Err: 27.85cm
# Epoch: 2/100. Step 6/100. Loss: 6.25. Err: 27.61cm
# Epoch: 2/100. Step 7/100. Loss: 6.25. Err: 27.8cm
# Epoch: 2/100. Step 8/100. Loss: 6.25. Err: 27.52cm
# Epoch: 2/100. Step 9/100. Loss: 6.25. Err: 27.74cm
# Epoch: 2/100. Step 10/100. Loss: 6.25. Err: 27.62cm
# Epoch: 2/100. Step 11/100. Loss: 6.25. Err: 27.84cm
# Epoch: 2/100. Step 12/100. Loss: 6.25. Err: 27.8cm
# Epoch: 2/100. Step 13/100. Loss: 6.25. Err: 27.89cm
# Epoch: 2/100. Step 14/100. Loss: 6.25. Err: 27.94cm
# Epoch: 2/100. Step 15/100. Loss: 6.25. Err: 27.9cm
# Epoch: 2/100. Step 16/100. Loss: 6.25. Err: 27.75cm
# Epoch: 2/100. Step 17/100. Loss: 6.25. Err: 27.61cm
# Epoch: 2/100. Step 18/100. Loss: 6.25. Err: 28.02cm
# Epoch: 2/100. Step 19/100. Loss: 6.25. Err: 27.56cm
# Epoch: 2/100. Step 20/100. Loss: 6.25. Err: 27.8cm
# Epoch: 2/100. Step 21/100. Loss: 6.25. Err: 27.83cm
# Epoch: 2/100. Step 22/100. Loss: 6.25. Err: 27.79cm
# Epoch: 2/100. Step 23/100. Loss: 6.25. Err: 27.37cm
# Epoch: 2/100. Step 24/100. Loss: 6.25. Err: 27.58cm
# Epoch: 2/100. Step 25/100. Loss: 6.25. Err: 27.82cm
# Epoch: 2/100. Step 26/100. Loss: 6.25. Err: 27.68cm
# Epoch: 2/100. Step 27/100. Loss: 6.25. Err: 27.71cm
# Epoch: 2/100. Step 28/100. Loss: 6.25. Err: 27.58cm
# Epoch: 2/100. Step 29/100. Loss: 6.24. Err: 27.81cm
# Epoch: 2/100. Step 30/100. Loss: 6.24. Err: 27.64cm
# Epoch: 2/100. Step 31/100. Loss: 6.24. Err: 27.3cm
# Epoch: 2/100. Step 32/100. Loss: 6.24. Err: 27.72cm
# Epoch: 2/100. Step 33/100. Loss: 6.24. Err: 27.62cm
# Epoch: 2/100. Step 34/100. Loss: 6.24. Err: 27.8cm
# Epoch: 2/100. Step 35/100. Loss: 6.24. Err: 27.83cm
# Epoch: 2/100. Step 36/100. Loss: 6.24. Err: 27.55cm
# Epoch: 2/100. Step 37/100. Loss: 6.24. Err: 27.83cm
# Epoch: 2/100. Step 38/100. Loss: 6.24. Err: 27.55cm
# Epoch: 2/100. Step 39/100. Loss: 6.24. Err: 27.65cm
# Epoch: 2/100. Step 40/100. Loss: 6.24. Err: 27.92cm
# Epoch: 2/100. Step 41/100. Loss: 6.24. Err: 27.72cm
# Epoch: 2/100. Step 42/100. Loss: 6.24. Err: 27.7cm
# Epoch: 2/100. Step 43/100. Loss: 6.24. Err: 27.73cm
# Epoch: 2/100. Step 44/100. Loss: 6.24. Err: 27.72cm
# Epoch: 2/100. Step 45/100. Loss: 6.24. Err: 27.8cm
# Epoch: 2/100. Step 46/100. Loss: 6.24. Err: 27.65cm
# Epoch: 2/100. Step 47/100. Loss: 6.24. Err: 27.65cm
# Epoch: 2/100. Step 48/100. Loss: 6.24. Err: 27.67cm
# Epoch: 2/100. Step 49/100. Loss: 6.24. Err: 27.72cm
# Epoch: 2/100. Step 50/100. Loss: 6.24. Err: 27.45cm
# Epoch: 2/100. Step 51/100. Loss: 6.24. Err: 27.77cm
# Epoch: 2/100. Step 52/100. Loss: 6.24. Err: 27.63cm
# Epoch: 2/100. Step 53/100. Loss: 6.24. Err: 27.57cm
# Epoch: 2/100. Step 54/100. Loss: 6.24. Err: 27.41cm
# Epoch: 2/100. Step 55/100. Loss: 6.24. Err: 27.58cm
# Epoch: 2/100. Step 56/100. Loss: 6.24. Err: 27.62cm
# Epoch: 2/100. Step 57/100. Loss: 6.24. Err: 27.72cm
# Epoch: 2/100. Step 58/100. Loss: 6.24. Err: 27.69cm
# Epoch: 2/100. Step 59/100. Loss: 6.24. Err: 27.54cm
# Epoch: 2/100. Step 60/100. Loss: 6.24. Err: 27.59cm
# Epoch: 2/100. Step 61/100. Loss: 6.24. Err: 27.59cm
# Epoch: 2/100. Step 62/100. Loss: 6.24. Err: 27.7cm
# Epoch: 2/100. Step 63/100. Loss: 6.24. Err: 27.62cm
# Epoch: 2/100. Step 64/100. Loss: 6.24. Err: 27.68cm
# Epoch: 2/100. Step 65/100. Loss: 6.24. Err: 27.66cm
# Epoch: 2/100. Step 66/100. Loss: 6.24. Err: 27.81cm
# Epoch: 2/100. Step 67/100. Loss: 6.24. Err: 27.61cm
# Epoch: 2/100. Step 68/100. Loss: 6.24. Err: 27.54cm
# Epoch: 2/100. Step 69/100. Loss: 6.24. Err: 27.94cm
# Epoch: 2/100. Step 70/100. Loss: 6.24. Err: 27.69cm
# Epoch: 2/100. Step 71/100. Loss: 6.24. Err: 27.53cm
# Epoch: 2/100. Step 72/100. Loss: 6.24. Err: 27.7cm
# Epoch: 2/100. Step 73/100. Loss: 6.24. Err: 27.65cm
# Epoch: 2/100. Step 74/100. Loss: 6.24. Err: 27.57cm
# Epoch: 2/100. Step 75/100. Loss: 6.24. Err: 27.76cm
# Epoch: 2/100. Step 76/100. Loss: 6.24. Err: 27.64cm
# Epoch: 2/100. Step 77/100. Loss: 6.24. Err: 27.8cm
# Epoch: 2/100. Step 78/100. Loss: 6.24. Err: 27.55cm
# Epoch: 2/100. Step 79/100. Loss: 6.24. Err: 27.47cm
# Epoch: 2/100. Step 80/100. Loss: 6.24. Err: 27.38cm
# Epoch: 2/100. Step 81/100. Loss: 6.24. Err: 27.68cm
# Epoch: 2/100. Step 82/100. Loss: 6.24. Err: 27.85cm
# Epoch: 2/100. Step 83/100. Loss: 6.24. Err: 27.34cm
# Epoch: 2/100. Step 84/100. Loss: 6.24. Err: 27.56cm
# Epoch: 2/100. Step 85/100. Loss: 6.24. Err: 27.38cm
# Epoch: 2/100. Step 86/100. Loss: 6.24. Err: 27.74cm
# Epoch: 2/100. Step 87/100. Loss: 6.24. Err: 27.35cm
# Epoch: 2/100. Step 88/100. Loss: 6.24. Err: 27.76cm
# Epoch: 2/100. Step 89/100. Loss: 6.24. Err: 27.58cm
# Epoch: 2/100. Step 90/100. Loss: 6.24. Err: 27.42cm
# Epoch: 2/100. Step 91/100. Loss: 6.24. Err: 27.47cm
# Epoch: 2/100. Step 92/100. Loss: 6.24. Err: 27.61cm
# Epoch: 2/100. Step 93/100. Loss: 6.24. Err: 27.8cm
# Epoch: 2/100. Step 94/100. Loss: 6.24. Err: 27.72cm
# Epoch: 2/100. Step 95/100. Loss: 6.24. Err: 27.53cm
# Epoch: 2/100. Step 96/100. Loss: 6.24. Err: 27.57cm
# Epoch: 2/100. Step 97/100. Loss: 6.24. Err: 27.4cm
# Epoch: 2/100. Step 98/100. Loss: 6.24. Err: 27.66cm
# Epoch: 2/100. Step 99/100. Loss: 6.24. Err: 27.39cm
# Epoch: 3/100. Step 0/100. Loss: 6.24. Err: 27.61cm
# Epoch: 3/100. Step 1/100. Loss: 6.24. Err: 27.57cm
# Epoch: 3/100. Step 2/100. Loss: 6.24. Err: 27.67cm
# Epoch: 3/100. Step 3/100. Loss: 6.24. Err: 27.59cm
# Epoch: 3/100. Step 4/100. Loss: 6.24. Err: 27.76cm
# Epoch: 3/100. Step 5/100. Loss: 6.24. Err: 27.15cm
# Epoch: 3/100. Step 6/100. Loss: 6.24. Err: 27.42cm
# Epoch: 3/100. Step 7/100. Loss: 6.24. Err: 27.63cm
# Epoch: 3/100. Step 8/100. Loss: 6.24. Err: 27.28cm
# Epoch: 3/100. Step 9/100. Loss: 6.24. Err: 27.54cm
# Epoch: 3/100. Step 10/100. Loss: 6.24. Err: 27.56cm
# Epoch: 3/100. Step 11/100. Loss: 6.24. Err: 27.36cm
# Epoch: 3/100. Step 12/100. Loss: 6.24. Err: 27.68cm
# Epoch: 3/100. Step 13/100. Loss: 6.24. Err: 27.66cm
# Epoch: 3/100. Step 14/100. Loss: 6.24. Err: 27.59cm
# Epoch: 3/100. Step 15/100. Loss: 6.24. Err: 27.54cm
# Epoch: 3/100. Step 16/100. Loss: 6.24. Err: 27.39cm
# Epoch: 3/100. Step 17/100. Loss: 6.24. Err: 27.65cm
# Epoch: 3/100. Step 18/100. Loss: 6.24. Err: 27.62cm
# Epoch: 3/100. Step 19/100. Loss: 6.24. Err: 27.48cm
# Epoch: 3/100. Step 20/100. Loss: 6.24. Err: 27.59cm
# Epoch: 3/100. Step 21/100. Loss: 6.24. Err: 27.34cm
# Epoch: 3/100. Step 22/100. Loss: 6.24. Err: 27.64cm
# Epoch: 3/100. Step 23/100. Loss: 6.24. Err: 27.48cm
# Epoch: 3/100. Step 24/100. Loss: 6.24. Err: 27.48cm
# Epoch: 3/100. Step 25/100. Loss: 6.24. Err: 27.4cm
# Epoch: 3/100. Step 26/100. Loss: 6.24. Err: 27.6cm
# Epoch: 3/100. Step 27/100. Loss: 6.24. Err: 27.47cm
# Epoch: 3/100. Step 28/100. Loss: 6.24. Err: 27.59cm
# Epoch: 3/100. Step 29/100. Loss: 6.24. Err: 27.52cm
# Epoch: 3/100. Step 30/100. Loss: 6.24. Err: 27.41cm
# Epoch: 3/100. Step 31/100. Loss: 6.24. Err: 27.46cm
# Epoch: 3/100. Step 32/100. Loss: 6.24. Err: 27.71cm
# Epoch: 3/100. Step 33/100. Loss: 6.24. Err: 27.5cm
# Epoch: 3/100. Step 34/100. Loss: 6.24. Err: 27.51cm
# Epoch: 3/100. Step 35/100. Loss: 6.24. Err: 27.68cm
# Epoch: 3/100. Step 36/100. Loss: 6.24. Err: 27.29cm
# Epoch: 3/100. Step 37/100. Loss: 6.24. Err: 27.77cm
# Epoch: 3/100. Step 38/100. Loss: 6.24. Err: 27.59cm
# Epoch: 3/100. Step 39/100. Loss: 6.24. Err: 27.43cm
# Epoch: 3/100. Step 40/100. Loss: 6.24. Err: 27.37cm
# Epoch: 3/100. Step 41/100. Loss: 6.24. Err: 27.55cm
# Epoch: 3/100. Step 42/100. Loss: 6.24. Err: 27.27cm
# Epoch: 3/100. Step 43/100. Loss: 6.24. Err: 27.49cm
# Epoch: 3/100. Step 44/100. Loss: 6.24. Err: 27.48cm
# Epoch: 3/100. Step 45/100. Loss: 6.24. Err: 27.56cm
# Epoch: 3/100. Step 46/100. Loss: 6.24. Err: 27.43cm
# Epoch: 3/100. Step 47/100. Loss: 6.24. Err: 27.46cm
# Epoch: 3/100. Step 48/100. Loss: 6.24. Err: 27.48cm
# Epoch: 3/100. Step 49/100. Loss: 6.24. Err: 27.3cm
# Epoch: 3/100. Step 50/100. Loss: 6.24. Err: 27.57cm
# Epoch: 3/100. Step 51/100. Loss: 6.24. Err: 27.47cm
# Epoch: 3/100. Step 52/100. Loss: 6.24. Err: 27.6cm
# Epoch: 3/100. Step 53/100. Loss: 6.24. Err: 27.72cm
# Epoch: 3/100. Step 54/100. Loss: 6.24. Err: 27.06cm
# Epoch: 3/100. Step 55/100. Loss: 6.24. Err: 27.49cm
# Epoch: 3/100. Step 56/100. Loss: 6.24. Err: 27.54cm
# Epoch: 3/100. Step 57/100. Loss: 6.24. Err: 27.53cm
# Epoch: 3/100. Step 58/100. Loss: 6.24. Err: 27.53cm
# Epoch: 3/100. Step 59/100. Loss: 6.24. Err: 27.25cm
# Epoch: 3/100. Step 60/100. Loss: 6.24. Err: 27.38cm
# Epoch: 3/100. Step 61/100. Loss: 6.24. Err: 27.63cm
# Epoch: 3/100. Step 62/100. Loss: 6.24. Err: 27.4cm
# Epoch: 3/100. Step 63/100. Loss: 6.24. Err: 27.27cm
# Epoch: 3/100. Step 64/100. Loss: 6.24. Err: 27.4cm
# Epoch: 3/100. Step 65/100. Loss: 6.24. Err: 27.41cm
# Epoch: 3/100. Step 66/100. Loss: 6.24. Err: 27.12cm
# Epoch: 3/100. Step 67/100. Loss: 6.24. Err: 27.34cm
# Epoch: 3/100. Step 68/100. Loss: 6.24. Err: 27.37cm
# Epoch: 3/100. Step 69/100. Loss: 6.24. Err: 27.53cm
# Epoch: 3/100. Step 70/100. Loss: 6.24. Err: 27.43cm
# Epoch: 3/100. Step 71/100. Loss: 6.24. Err: 27.45cm
# Epoch: 3/100. Step 72/100. Loss: 6.24. Err: 27.58cm
# Epoch: 3/100. Step 73/100. Loss: 6.24. Err: 27.63cm
# Epoch: 3/100. Step 74/100. Loss: 6.24. Err: 27.17cm
# Epoch: 3/100. Step 75/100. Loss: 6.24. Err: 27.36cm
# Epoch: 3/100. Step 76/100. Loss: 6.24. Err: 27.19cm
# Epoch: 3/100. Step 77/100. Loss: 6.24. Err: 27.22cm
# Epoch: 3/100. Step 78/100. Loss: 6.24. Err: 27.56cm
# Epoch: 3/100. Step 79/100. Loss: 6.24. Err: 27.41cm
# Epoch: 3/100. Step 80/100. Loss: 6.24. Err: 27.38cm
# Epoch: 3/100. Step 81/100. Loss: 6.24. Err: 27.22cm
# Epoch: 3/100. Step 82/100. Loss: 6.24. Err: 27.63cm
# Epoch: 3/100. Step 83/100. Loss: 6.24. Err: 27.48cm
# Epoch: 3/100. Step 84/100. Loss: 6.24. Err: 27.48cm
# Epoch: 3/100. Step 85/100. Loss: 6.24. Err: 27.66cm
# Epoch: 3/100. Step 86/100. Loss: 6.24. Err: 27.14cm
# Epoch: 3/100. Step 87/100. Loss: 6.24. Err: 27.44cm
# Epoch: 3/100. Step 88/100. Loss: 6.24. Err: 27.57cm
# Epoch: 3/100. Step 89/100. Loss: 6.24. Err: 27.71cm
# Epoch: 3/100. Step 90/100. Loss: 6.24. Err: 27.35cm
# Epoch: 3/100. Step 91/100. Loss: 6.24. Err: 27.54cm
# Epoch: 3/100. Step 92/100. Loss: 6.24. Err: 27.37cm
# Epoch: 3/100. Step 93/100. Loss: 6.24. Err: 27.74cm
# Epoch: 3/100. Step 94/100. Loss: 6.24. Err: 27.58cm
# Epoch: 3/100. Step 95/100. Loss: 6.24. Err: 27.45cm
# Epoch: 3/100. Step 96/100. Loss: 6.24. Err: 27.53cm
# Epoch: 3/100. Step 97/100. Loss: 6.24. Err: 27.59cm
# Epoch: 3/100. Step 98/100. Loss: 6.24. Err: 27.58cm
# Epoch: 3/100. Step 99/100. Loss: 6.24. Err: 27.39cm
# Epoch: 4/100. Step 0/100. Loss: 6.24. Err: 27.2cm
# Epoch: 4/100. Step 1/100. Loss: 6.24. Err: 27.31cm
# Epoch: 4/100. Step 2/100. Loss: 6.24. Err: 27.63cm
# Epoch: 4/100. Step 3/100. Loss: 6.24. Err: 27.49cm
# Epoch: 4/100. Step 4/100. Loss: 6.24. Err: 27.31cm
# Epoch: 4/100. Step 5/100. Loss: 6.24. Err: 27.58cm
# Epoch: 4/100. Step 6/100. Loss: 6.24. Err: 27.1cm
# Epoch: 4/100. Step 7/100. Loss: 6.24. Err: 27.22cm
# Epoch: 4/100. Step 8/100. Loss: 6.24. Err: 27.21cm
# Epoch: 4/100. Step 9/100. Loss: 6.24. Err: 27.46cm
# Epoch: 4/100. Step 10/100. Loss: 6.24. Err: 27.37cm
# Epoch: 4/100. Step 11/100. Loss: 6.24. Err: 27.15cm
# Epoch: 4/100. Step 12/100. Loss: 6.24. Err: 27.48cm
# Epoch: 4/100. Step 13/100. Loss: 6.24. Err: 27.35cm
# Epoch: 4/100. Step 14/100. Loss: 6.24. Err: 27.28cm
# Epoch: 4/100. Step 15/100. Loss: 6.24. Err: 27.53cm
# Epoch: 4/100. Step 16/100. Loss: 6.24. Err: 27.31cm
# Epoch: 4/100. Step 17/100. Loss: 6.24. Err: 27.69cm
# Epoch: 4/100. Step 18/100. Loss: 6.24. Err: 27.44cm
# Epoch: 4/100. Step 19/100. Loss: 6.24. Err: 27.48cm
# Epoch: 4/100. Step 20/100. Loss: 6.24. Err: 27.37cm
# Epoch: 4/100. Step 21/100. Loss: 6.24. Err: 27.44cm
# Epoch: 4/100. Step 22/100. Loss: 6.24. Err: 27.11cm
# Epoch: 4/100. Step 23/100. Loss: 6.24. Err: 27.51cm
# Epoch: 4/100. Step 24/100. Loss: 6.24. Err: 27.13cm
# Epoch: 4/100. Step 25/100. Loss: 6.24. Err: 27.55cm
# Epoch: 4/100. Step 26/100. Loss: 6.24. Err: 27.32cm
# Epoch: 4/100. Step 27/100. Loss: 6.24. Err: 27.06cm
# Epoch: 4/100. Step 28/100. Loss: 6.24. Err: 27.58cm
# Epoch: 4/100. Step 29/100. Loss: 6.24. Err: 27.43cm
# Epoch: 4/100. Step 30/100. Loss: 6.24. Err: 27.68cm
# Epoch: 4/100. Step 31/100. Loss: 6.24. Err: 27.46cm
# Epoch: 4/100. Step 32/100. Loss: 6.24. Err: 27.29cm
# Epoch: 4/100. Step 33/100. Loss: 6.24. Err: 27.53cm
# Epoch: 4/100. Step 34/100. Loss: 6.24. Err: 27.36cm
# Epoch: 4/100. Step 35/100. Loss: 6.24. Err: 27.3cm
# Epoch: 4/100. Step 36/100. Loss: 6.24. Err: 27.33cm
# Epoch: 4/100. Step 37/100. Loss: 6.24. Err: 27.25cm
# Epoch: 4/100. Step 38/100. Loss: 6.24. Err: 27.33cm
# Epoch: 4/100. Step 39/100. Loss: 6.24. Err: 27.68cm
# Epoch: 4/100. Step 40/100. Loss: 6.24. Err: 27.24cm
# Epoch: 4/100. Step 41/100. Loss: 6.24. Err: 27.41cm
# Epoch: 4/100. Step 42/100. Loss: 6.24. Err: 27.45cm
# Epoch: 4/100. Step 43/100. Loss: 6.24. Err: 27.6cm
# Epoch: 4/100. Step 44/100. Loss: 6.24. Err: 27.28cm
# Epoch: 4/100. Step 45/100. Loss: 6.24. Err: 27.3cm
# Epoch: 4/100. Step 46/100. Loss: 6.24. Err: 27.21cm
# Epoch: 4/100. Step 47/100. Loss: 6.24. Err: 27.25cm
# Epoch: 4/100. Step 48/100. Loss: 6.24. Err: 27.44cm
# Epoch: 4/100. Step 49/100. Loss: 6.24. Err: 27.22cm
# Epoch: 4/100. Step 50/100. Loss: 6.24. Err: 27.32cm
# Epoch: 4/100. Step 51/100. Loss: 6.24. Err: 27.48cm
# Epoch: 4/100. Step 52/100. Loss: 6.24. Err: 27.47cm
# Epoch: 4/100. Step 53/100. Loss: 6.24. Err: 27.41cm
# Epoch: 4/100. Step 54/100. Loss: 6.24. Err: 27.49cm
# Epoch: 4/100. Step 55/100. Loss: 6.24. Err: 27.22cm
# Epoch: 4/100. Step 56/100. Loss: 6.24. Err: 27.46cm
# Epoch: 4/100. Step 57/100. Loss: 6.24. Err: 27.46cm
# Epoch: 4/100. Step 58/100. Loss: 6.24. Err: 27.25cm
# Epoch: 4/100. Step 59/100. Loss: 6.24. Err: 27.44cm
# Epoch: 4/100. Step 60/100. Loss: 6.24. Err: 27.32cm
# Epoch: 4/100. Step 61/100. Loss: 6.24. Err: 27.32cm
# Epoch: 4/100. Step 62/100. Loss: 6.24. Err: 27.14cm
# Epoch: 4/100. Step 63/100. Loss: 6.24. Err: 27.36cm
# Epoch: 4/100. Step 64/100. Loss: 6.24. Err: 27.15cm
# Epoch: 4/100. Step 65/100. Loss: 6.24. Err: 27.37cm
# Epoch: 4/100. Step 66/100. Loss: 6.24. Err: 27.34cm
# Epoch: 4/100. Step 67/100. Loss: 6.24. Err: 27.37cm
# Epoch: 4/100. Step 68/100. Loss: 6.24. Err: 27.39cm
# Epoch: 4/100. Step 69/100. Loss: 6.24. Err: 27.35cm
# Epoch: 4/100. Step 70/100. Loss: 6.24. Err: 27.56cm
# Epoch: 4/100. Step 71/100. Loss: 6.24. Err: 27.52cm
# Epoch: 4/100. Step 72/100. Loss: 6.24. Err: 27.54cm
# Epoch: 4/100. Step 73/100. Loss: 6.24. Err: 27.09cm
# Epoch: 4/100. Step 74/100. Loss: 6.24. Err: 27.51cm
# Epoch: 4/100. Step 75/100. Loss: 6.24. Err: 27.56cm
# Epoch: 4/100. Step 76/100. Loss: 6.24. Err: 27.44cm
# Epoch: 4/100. Step 77/100. Loss: 6.24. Err: 27.21cm
# Epoch: 4/100. Step 78/100. Loss: 6.24. Err: 27.25cm
# Epoch: 4/100. Step 79/100. Loss: 6.24. Err: 27.4cm
# Epoch: 4/100. Step 80/100. Loss: 6.24. Err: 27.46cm
# Epoch: 4/100. Step 81/100. Loss: 6.24. Err: 27.52cm
# Epoch: 4/100. Step 82/100. Loss: 6.24. Err: 27.6cm
# Epoch: 4/100. Step 83/100. Loss: 6.24. Err: 27.25cm
# Epoch: 4/100. Step 84/100. Loss: 6.24. Err: 27.48cm
# Epoch: 4/100. Step 85/100. Loss: 6.24. Err: 27.43cm
# Epoch: 4/100. Step 86/100. Loss: 6.24. Err: 27.26cm
# Epoch: 4/100. Step 87/100. Loss: 6.24. Err: 27.42cm
# Epoch: 4/100. Step 88/100. Loss: 6.24. Err: 27.23cm
# Epoch: 4/100. Step 89/100. Loss: 6.24. Err: 27.44cm
# Epoch: 4/100. Step 90/100. Loss: 6.24. Err: 27.49cm
# Epoch: 4/100. Step 91/100. Loss: 6.24. Err: 27.11cm
# Epoch: 4/100. Step 92/100. Loss: 6.24. Err: 27.23cm
# Epoch: 4/100. Step 93/100. Loss: 6.24. Err: 27.23cm
# Epoch: 4/100. Step 94/100. Loss: 6.24. Err: 27.49cm
# Epoch: 4/100. Step 95/100. Loss: 6.24. Err: 27.34cm
# Epoch: 4/100. Step 96/100. Loss: 6.24. Err: 27.55cm
# Epoch: 4/100. Step 97/100. Loss: 6.24. Err: 27.18cm
# Epoch: 4/100. Step 98/100. Loss: 6.24. Err: 27.33cm
# Epoch: 4/100. Step 99/100. Loss: 6.24. Err: 27.32cm
# Epoch: 5/100. Step 0/100. Loss: 6.24. Err: 27.54cm
# Epoch: 5/100. Step 1/100. Loss: 6.24. Err: 27.23cm
# Epoch: 5/100. Step 2/100. Loss: 6.24. Err: 27.47cm
# Epoch: 5/100. Step 3/100. Loss: 6.24. Err: 27.39cm
# Epoch: 5/100. Step 4/100. Loss: 6.24. Err: 27.1cm
# Epoch: 5/100. Step 5/100. Loss: 6.24. Err: 27.27cm
# Epoch: 5/100. Step 6/100. Loss: 6.24. Err: 27.28cm
# Epoch: 5/100. Step 7/100. Loss: 6.24. Err: 27.25cm
# Epoch: 5/100. Step 8/100. Loss: 6.24. Err: 27.42cm
# Epoch: 5/100. Step 9/100. Loss: 6.24. Err: 27.12cm
# Epoch: 5/100. Step 10/100. Loss: 6.24. Err: 27.25cm
# Epoch: 5/100. Step 11/100. Loss: 6.24. Err: 27.31cm
# Epoch: 5/100. Step 12/100. Loss: 6.24. Err: 27.35cm
# Epoch: 5/100. Step 13/100. Loss: 6.24. Err: 27.34cm
# Epoch: 5/100. Step 14/100. Loss: 6.24. Err: 27.61cm
# Epoch: 5/100. Step 15/100. Loss: 6.24. Err: 27.34cm
# Epoch: 5/100. Step 16/100. Loss: 6.24. Err: 27.25cm
# Epoch: 5/100. Step 17/100. Loss: 6.24. Err: 27.42cm
# Epoch: 5/100. Step 18/100. Loss: 6.24. Err: 27.46cm
# Epoch: 5/100. Step 19/100. Loss: 6.24. Err: 27.33cm
# Epoch: 5/100. Step 20/100. Loss: 6.24. Err: 27.15cm
# Epoch: 5/100. Step 21/100. Loss: 6.24. Err: 27.35cm
# Epoch: 5/100. Step 22/100. Loss: 6.24. Err: 27.3cm
# Epoch: 5/100. Step 23/100. Loss: 6.24. Err: 27.46cm
# Epoch: 5/100. Step 24/100. Loss: 6.24. Err: 27.41cm
# Epoch: 5/100. Step 25/100. Loss: 6.24. Err: 27.39cm
# Epoch: 5/100. Step 26/100. Loss: 6.24. Err: 27.24cm
# Epoch: 5/100. Step 27/100. Loss: 6.24. Err: 27.5cm
# Epoch: 5/100. Step 28/100. Loss: 6.24. Err: 27.24cm
# Epoch: 5/100. Step 29/100. Loss: 6.24. Err: 27.29cm
# Epoch: 5/100. Step 30/100. Loss: 6.24. Err: 27.37cm
# Epoch: 5/100. Step 31/100. Loss: 6.24. Err: 27.42cm
# Epoch: 5/100. Step 32/100. Loss: 6.24. Err: 27.33cm
# Epoch: 5/100. Step 33/100. Loss: 6.24. Err: 27.34cm
# Epoch: 5/100. Step 34/100. Loss: 6.24. Err: 27.38cm
# Epoch: 5/100. Step 35/100. Loss: 6.24. Err: 27.37cm
# Epoch: 5/100. Step 36/100. Loss: 6.24. Err: 27.37cm
# Epoch: 5/100. Step 37/100. Loss: 6.24. Err: 27.37cm
# Epoch: 5/100. Step 38/100. Loss: 6.24. Err: 27.31cm
# Epoch: 5/100. Step 39/100. Loss: 6.24. Err: 27.3cm
# Epoch: 5/100. Step 40/100. Loss: 6.24. Err: 27.76cm
# Epoch: 5/100. Step 41/100. Loss: 6.24. Err: 27.09cm
# Epoch: 5/100. Step 42/100. Loss: 6.24. Err: 27.37cm
# Epoch: 5/100. Step 43/100. Loss: 6.24. Err: 27.33cm
# Epoch: 5/100. Step 44/100. Loss: 6.24. Err: 27.31cm
# Epoch: 5/100. Step 45/100. Loss: 6.24. Err: 27.44cm
# Epoch: 5/100. Step 46/100. Loss: 6.24. Err: 27.54cm
# Epoch: 5/100. Step 47/100. Loss: 6.24. Err: 27.49cm
# Epoch: 5/100. Step 48/100. Loss: 6.24. Err: 27.28cm
# Epoch: 5/100. Step 49/100. Loss: 6.24. Err: 27.23cm
# Epoch: 5/100. Step 50/100. Loss: 6.24. Err: 27.6cm
# Epoch: 5/100. Step 51/100. Loss: 6.24. Err: 27.21cm
# Epoch: 5/100. Step 52/100. Loss: 6.24. Err: 27.3cm
# Epoch: 5/100. Step 53/100. Loss: 6.24. Err: 27.12cm
# Epoch: 5/100. Step 54/100. Loss: 6.24. Err: 27.43cm
# Epoch: 5/100. Step 55/100. Loss: 6.24. Err: 27.18cm
# Epoch: 5/100. Step 56/100. Loss: 6.24. Err: 27.22cm
# Epoch: 5/100. Step 57/100. Loss: 6.24. Err: 27.46cm
# Epoch: 5/100. Step 58/100. Loss: 6.24. Err: 27.34cm
# Epoch: 5/100. Step 59/100. Loss: 6.24. Err: 27.26cm
# Epoch: 5/100. Step 60/100. Loss: 6.24. Err: 27.31cm
# Epoch: 5/100. Step 61/100. Loss: 6.24. Err: 27.25cm
# Epoch: 5/100. Step 62/100. Loss: 6.24. Err: 27.53cm
# Epoch: 5/100. Step 63/100. Loss: 6.24. Err: 27.17cm
# Epoch: 5/100. Step 64/100. Loss: 6.24. Err: 27.31cm
# Epoch: 5/100. Step 65/100. Loss: 6.24. Err: 27.51cm
# Epoch: 5/100. Step 66/100. Loss: 6.24. Err: 27.2cm
# Epoch: 5/100. Step 67/100. Loss: 6.24. Err: 27.39cm
# Epoch: 5/100. Step 68/100. Loss: 6.24. Err: 27.38cm
# Epoch: 5/100. Step 69/100. Loss: 6.24. Err: 27.52cm
# Epoch: 5/100. Step 70/100. Loss: 6.24. Err: 27.49cm
# Epoch: 5/100. Step 71/100. Loss: 6.24. Err: 27.41cm
# Epoch: 5/100. Step 72/100. Loss: 6.24. Err: 27.27cm
# Epoch: 5/100. Step 73/100. Loss: 6.24. Err: 27.19cm
# Epoch: 5/100. Step 74/100. Loss: 6.24. Err: 27.33cm
# Epoch: 5/100. Step 75/100. Loss: 6.24. Err: 27.22cm
# Epoch: 5/100. Step 76/100. Loss: 6.24. Err: 27.26cm
# Epoch: 5/100. Step 77/100. Loss: 6.24. Err: 27.48cm
# Epoch: 5/100. Step 78/100. Loss: 6.24. Err: 27.32cm
# Epoch: 5/100. Step 79/100. Loss: 6.24. Err: 27.41cm
# Epoch: 5/100. Step 80/100. Loss: 6.24. Err: 27.44cm
# Epoch: 5/100. Step 81/100. Loss: 6.24. Err: 27.34cm
# Epoch: 5/100. Step 82/100. Loss: 6.24. Err: 27.17cm
# Epoch: 5/100. Step 83/100. Loss: 6.24. Err: 27.33cm
# Epoch: 5/100. Step 84/100. Loss: 6.24. Err: 27.5cm
# Epoch: 5/100. Step 85/100. Loss: 6.24. Err: 27.47cm
# Epoch: 5/100. Step 86/100. Loss: 6.24. Err: 27.16cm
# Epoch: 5/100. Step 87/100. Loss: 6.24. Err: 27.38cm
# Epoch: 5/100. Step 88/100. Loss: 6.24. Err: 27.51cm
# Epoch: 5/100. Step 89/100. Loss: 6.24. Err: 27.4cm
# Epoch: 5/100. Step 90/100. Loss: 6.24. Err: 27.35cm
# Epoch: 5/100. Step 91/100. Loss: 6.24. Err: 27.29cm
# Epoch: 5/100. Step 92/100. Loss: 6.24. Err: 27.24cm
# Epoch: 5/100. Step 93/100. Loss: 6.24. Err: 27.32cm
# Epoch: 5/100. Step 94/100. Loss: 6.24. Err: 27.29cm
# Epoch: 5/100. Step 95/100. Loss: 6.24. Err: 27.36cm
# Epoch: 5/100. Step 96/100. Loss: 6.24. Err: 27.34cm
# Epoch: 5/100. Step 97/100. Loss: 6.24. Err: 27.32cm
# Epoch: 5/100. Step 98/100. Loss: 6.24. Err: 27.41cm
# Epoch: 5/100. Step 99/100. Loss: 6.24. Err: 27.11cm
# Epoch: 6/100. Step 0/100. Loss: 6.24. Err: 27.18cm
# Epoch: 6/100. Step 1/100. Loss: 6.24. Err: 27.2cm
# Epoch: 6/100. Step 2/100. Loss: 6.24. Err: 27.52cm
# Epoch: 6/100. Step 3/100. Loss: 6.24. Err: 27.14cm
# Epoch: 6/100. Step 4/100. Loss: 6.24. Err: 27.14cm
# Epoch: 6/100. Step 5/100. Loss: 6.24. Err: 27.34cm
# Epoch: 6/100. Step 6/100. Loss: 6.24. Err: 27.46cm
# Epoch: 6/100. Step 7/100. Loss: 6.24. Err: 27.32cm
# Epoch: 6/100. Step 8/100. Loss: 6.24. Err: 27.31cm
# Epoch: 6/100. Step 9/100. Loss: 6.24. Err: 27.63cm
# Epoch: 6/100. Step 10/100. Loss: 6.24. Err: 27.55cm
# Epoch: 6/100. Step 11/100. Loss: 6.24. Err: 27.13cm
# Epoch: 6/100. Step 12/100. Loss: 6.24. Err: 27.36cm
# Epoch: 6/100. Step 13/100. Loss: 6.24. Err: 27.49cm
# Epoch: 6/100. Step 14/100. Loss: 6.24. Err: 27.43cm
# Epoch: 6/100. Step 15/100. Loss: 6.24. Err: 27.31cm
# Epoch: 6/100. Step 16/100. Loss: 6.24. Err: 27.56cm
# Epoch: 6/100. Step 17/100. Loss: 6.24. Err: 27.31cm
# Epoch: 6/100. Step 18/100. Loss: 6.24. Err: 27.46cm
# Epoch: 6/100. Step 19/100. Loss: 6.24. Err: 27.24cm
# Epoch: 6/100. Step 20/100. Loss: 6.24. Err: 27.08cm
# Epoch: 6/100. Step 21/100. Loss: 6.24. Err: 27.34cm
# Epoch: 6/100. Step 22/100. Loss: 6.24. Err: 27.35cm
# Epoch: 6/100. Step 23/100. Loss: 6.24. Err: 27.36cm
# Epoch: 6/100. Step 24/100. Loss: 6.24. Err: 27.2cm
# Epoch: 6/100. Step 25/100. Loss: 6.24. Err: 27.19cm
# Epoch: 6/100. Step 26/100. Loss: 6.24. Err: 27.2cm
# Epoch: 6/100. Step 27/100. Loss: 6.24. Err: 27.2cm
# Epoch: 6/100. Step 28/100. Loss: 6.24. Err: 27.42cm
# Epoch: 6/100. Step 29/100. Loss: 6.24. Err: 27.05cm
# Epoch: 6/100. Step 30/100. Loss: 6.24. Err: 27.27cm
# Epoch: 6/100. Step 31/100. Loss: 6.24. Err: 27.16cm
# Epoch: 6/100. Step 32/100. Loss: 6.24. Err: 27.42cm
# Epoch: 6/100. Step 33/100. Loss: 6.24. Err: 27.46cm
# Epoch: 6/100. Step 34/100. Loss: 6.24. Err: 27.14cm
# Epoch: 6/100. Step 35/100. Loss: 6.24. Err: 27.33cm
# Epoch: 6/100. Step 36/100. Loss: 6.24. Err: 27.29cm
# Epoch: 6/100. Step 37/100. Loss: 6.24. Err: 27.26cm
# Epoch: 6/100. Step 38/100. Loss: 6.24. Err: 27.26cm
# Epoch: 6/100. Step 39/100. Loss: 6.24. Err: 27.39cm
# Epoch: 6/100. Step 40/100. Loss: 6.24. Err: 27.23cm
# Epoch: 6/100. Step 41/100. Loss: 6.24. Err: 27.34cm
# Epoch: 6/100. Step 42/100. Loss: 6.24. Err: 27.21cm
# Epoch: 6/100. Step 43/100. Loss: 6.24. Err: 27.46cm
# Epoch: 6/100. Step 44/100. Loss: 6.24. Err: 27.47cm
# Epoch: 6/100. Step 45/100. Loss: 6.24. Err: 27.23cm
# Epoch: 6/100. Step 46/100. Loss: 6.24. Err: 27.18cm
# Epoch: 6/100. Step 47/100. Loss: 6.24. Err: 27.41cm
# Epoch: 6/100. Step 48/100. Loss: 6.24. Err: 27.41cm
# Epoch: 6/100. Step 49/100. Loss: 6.24. Err: 27.27cm
# Epoch: 6/100. Step 50/100. Loss: 6.24. Err: 27.19cm
# Epoch: 6/100. Step 51/100. Loss: 6.24. Err: 27.28cm
# Epoch: 6/100. Step 52/100. Loss: 6.24. Err: 27.36cm
# Epoch: 6/100. Step 53/100. Loss: 6.24. Err: 27.41cm
# Epoch: 6/100. Step 54/100. Loss: 6.24. Err: 27.35cm
# Epoch: 6/100. Step 55/100. Loss: 6.24. Err: 27.4cm
# Epoch: 6/100. Step 56/100. Loss: 6.24. Err: 27.28cm
# Epoch: 6/100. Step 57/100. Loss: 6.24. Err: 27.36cm
# Epoch: 6/100. Step 58/100. Loss: 6.24. Err: 27.19cm
# Epoch: 6/100. Step 59/100. Loss: 6.24. Err: 27.16cm
# Epoch: 6/100. Step 60/100. Loss: 6.24. Err: 27.11cm
# Epoch: 6/100. Step 61/100. Loss: 6.24. Err: 27.4cm
# Epoch: 6/100. Step 62/100. Loss: 6.24. Err: 27.37cm
# Epoch: 6/100. Step 63/100. Loss: 6.24. Err: 27.44cm
# Epoch: 6/100. Step 64/100. Loss: 6.24. Err: 27.25cm
# Epoch: 6/100. Step 65/100. Loss: 6.24. Err: 27.23cm
# Epoch: 6/100. Step 66/100. Loss: 6.24. Err: 27.29cm
# Epoch: 6/100. Step 67/100. Loss: 6.24. Err: 27.26cm
# Epoch: 6/100. Step 68/100. Loss: 6.24. Err: 27.12cm
# Epoch: 6/100. Step 69/100. Loss: 6.24. Err: 27.24cm
# Epoch: 6/100. Step 70/100. Loss: 6.24. Err: 27.44cm
# Epoch: 6/100. Step 71/100. Loss: 6.24. Err: 27.39cm
# Epoch: 6/100. Step 72/100. Loss: 6.24. Err: 27.24cm
# Epoch: 6/100. Step 73/100. Loss: 6.24. Err: 27.53cm
# Epoch: 6/100. Step 74/100. Loss: 6.24. Err: 27.44cm
# Epoch: 6/100. Step 75/100. Loss: 6.24. Err: 27.66cm
# Epoch: 6/100. Step 76/100. Loss: 6.24. Err: 27.47cm
# Epoch: 6/100. Step 77/100. Loss: 6.24. Err: 27.3cm
# Epoch: 6/100. Step 78/100. Loss: 6.24. Err: 27.54cm
# Epoch: 6/100. Step 79/100. Loss: 6.24. Err: 27.28cm
# Epoch: 6/100. Step 80/100. Loss: 6.24. Err: 27.13cm
# Epoch: 6/100. Step 81/100. Loss: 6.24. Err: 27.37cm
# Epoch: 6/100. Step 82/100. Loss: 6.24. Err: 27.4cm
# Epoch: 6/100. Step 83/100. Loss: 6.24. Err: 27.23cm
# Epoch: 6/100. Step 84/100. Loss: 6.24. Err: 27.35cm
# Epoch: 6/100. Step 85/100. Loss: 6.24. Err: 27.21cm
# Epoch: 6/100. Step 86/100. Loss: 6.24. Err: 27.19cm
# Epoch: 6/100. Step 87/100. Loss: 6.24. Err: 27.29cm
# Epoch: 6/100. Step 88/100. Loss: 6.24. Err: 27.24cm
# Epoch: 6/100. Step 89/100. Loss: 6.24. Err: 27.33cm
# Epoch: 6/100. Step 90/100. Loss: 6.24. Err: 27.32cm
# Epoch: 6/100. Step 91/100. Loss: 6.24. Err: 27.41cm
# Epoch: 6/100. Step 92/100. Loss: 6.24. Err: 27.33cm
# Epoch: 6/100. Step 93/100. Loss: 6.24. Err: 27.44cm
# Epoch: 6/100. Step 94/100. Loss: 6.24. Err: 27.49cm
# Epoch: 6/100. Step 95/100. Loss: 6.24. Err: 27.66cm
# Epoch: 6/100. Step 96/100. Loss: 6.24. Err: 27.43cm
# Epoch: 6/100. Step 97/100. Loss: 6.24. Err: 27.31cm
# Epoch: 6/100. Step 98/100. Loss: 6.24. Err: 27.44cm
# Epoch: 6/100. Step 99/100. Loss: 6.24. Err: 27.24cm
# Epoch: 7/100. Step 0/100. Loss: 6.24. Err: 27.31cm
# Epoch: 7/100. Step 1/100. Loss: 6.24. Err: 27.11cm
# Epoch: 7/100. Step 2/100. Loss: 6.24. Err: 27.03cm
# Epoch: 7/100. Step 3/100. Loss: 6.24. Err: 27.22cm
# Epoch: 7/100. Step 4/100. Loss: 6.24. Err: 27.29cm
# Epoch: 7/100. Step 5/100. Loss: 6.24. Err: 27.16cm
# Epoch: 7/100. Step 6/100. Loss: 6.24. Err: 27.41cm
# Epoch: 7/100. Step 7/100. Loss: 6.24. Err: 27.15cm
# Epoch: 7/100. Step 8/100. Loss: 6.24. Err: 27.32cm
# Epoch: 7/100. Step 9/100. Loss: 6.24. Err: 27.42cm
# Epoch: 7/100. Step 10/100. Loss: 6.24. Err: 27.28cm
# Epoch: 7/100. Step 11/100. Loss: 6.24. Err: 27.38cm
# Epoch: 7/100. Step 12/100. Loss: 6.24. Err: 27.24cm
# Epoch: 7/100. Step 13/100. Loss: 6.24. Err: 27.29cm
# Epoch: 7/100. Step 14/100. Loss: 6.24. Err: 27.42cm
# Epoch: 7/100. Step 15/100. Loss: 6.24. Err: 27.28cm
# Epoch: 7/100. Step 16/100. Loss: 6.24. Err: 27.31cm
# Epoch: 7/100. Step 17/100. Loss: 6.24. Err: 27.2cm
# Epoch: 7/100. Step 18/100. Loss: 6.24. Err: 27.25cm
# Epoch: 7/100. Step 19/100. Loss: 6.24. Err: 27.45cm
# Epoch: 7/100. Step 20/100. Loss: 6.24. Err: 27.43cm
# Epoch: 7/100. Step 21/100. Loss: 6.24. Err: 27.25cm
# Epoch: 7/100. Step 22/100. Loss: 6.24. Err: 27.47cm
# Epoch: 7/100. Step 23/100. Loss: 6.24. Err: 27.42cm
# Epoch: 7/100. Step 24/100. Loss: 6.24. Err: 27.4cm
# Epoch: 7/100. Step 25/100. Loss: 6.24. Err: 27.47cm
# Epoch: 7/100. Step 26/100. Loss: 6.24. Err: 27.35cm
# Epoch: 7/100. Step 27/100. Loss: 6.24. Err: 27.28cm
# Epoch: 7/100. Step 28/100. Loss: 6.24. Err: 27.35cm
# Epoch: 7/100. Step 29/100. Loss: 6.24. Err: 27.4cm
# Epoch: 7/100. Step 30/100. Loss: 6.24. Err: 27.36cm
# Epoch: 7/100. Step 31/100. Loss: 6.24. Err: 27.43cm
# Epoch: 7/100. Step 32/100. Loss: 6.24. Err: 27.34cm
# Epoch: 7/100. Step 33/100. Loss: 6.24. Err: 27.54cm
# Epoch: 7/100. Step 34/100. Loss: 6.24. Err: 27.39cm
# Epoch: 7/100. Step 35/100. Loss: 6.24. Err: 27.42cm
# Epoch: 7/100. Step 36/100. Loss: 6.24. Err: 27.56cm
# Epoch: 7/100. Step 37/100. Loss: 6.24. Err: 27.4cm
# Epoch: 7/100. Step 38/100. Loss: 6.24. Err: 27.73cm
# Epoch: 7/100. Step 39/100. Loss: 6.24. Err: 27.44cm
# Epoch: 7/100. Step 40/100. Loss: 6.24. Err: 27.54cm
# Epoch: 7/100. Step 41/100. Loss: 6.24. Err: 27.36cm
# Epoch: 7/100. Step 42/100. Loss: 6.24. Err: 27.69cm
# Epoch: 7/100. Step 43/100. Loss: 6.24. Err: 27.67cm
# Epoch: 7/100. Step 44/100. Loss: 6.24. Err: 27.58cm
# Epoch: 7/100. Step 45/100. Loss: 6.24. Err: 27.45cm
# Epoch: 7/100. Step 46/100. Loss: 6.24. Err: 27.46cm
# Epoch: 7/100. Step 47/100. Loss: 6.24. Err: 27.47cm
# Epoch: 7/100. Step 48/100. Loss: 6.24. Err: 27.42cm
# Epoch: 7/100. Step 49/100. Loss: 6.24. Err: 27.42cm
# Epoch: 7/100. Step 50/100. Loss: 6.24. Err: 27.4cm
# Epoch: 7/100. Step 51/100. Loss: 6.24. Err: 27.41cm
# Epoch: 7/100. Step 52/100. Loss: 6.24. Err: 27.42cm
# Epoch: 7/100. Step 53/100. Loss: 6.24. Err: 27.52cm
# Epoch: 7/100. Step 54/100. Loss: 6.24. Err: 27.69cm
# Epoch: 7/100. Step 55/100. Loss: 6.24. Err: 27.4cm
# Epoch: 7/100. Step 56/100. Loss: 6.24. Err: 27.51cm
# Epoch: 7/100. Step 57/100. Loss: 6.24. Err: 27.2cm
# Epoch: 7/100. Step 58/100. Loss: 6.24. Err: 27.52cm
# Epoch: 7/100. Step 59/100. Loss: 6.24. Err: 27.58cm
# Epoch: 7/100. Step 60/100. Loss: 6.24. Err: 27.5cm
# Epoch: 7/100. Step 61/100. Loss: 6.24. Err: 27.56cm
# Epoch: 7/100. Step 62/100. Loss: 6.24. Err: 27.55cm
# Epoch: 7/100. Step 63/100. Loss: 6.24. Err: 27.41cm
# Epoch: 7/100. Step 64/100. Loss: 6.24. Err: 27.56cm
# Epoch: 7/100. Step 65/100. Loss: 6.24. Err: 27.42cm
# Epoch: 7/100. Step 66/100. Loss: 6.24. Err: 27.62cm
# Epoch: 7/100. Step 67/100. Loss: 6.24. Err: 27.6cm
# Epoch: 7/100. Step 68/100. Loss: 6.24. Err: 27.49cm
# Epoch: 7/100. Step 69/100. Loss: 6.24. Err: 27.54cm
# Epoch: 7/100. Step 70/100. Loss: 6.24. Err: 27.59cm
# Epoch: 7/100. Step 71/100. Loss: 6.24. Err: 27.67cm
# Epoch: 7/100. Step 72/100. Loss: 6.24. Err: 27.62cm
# Epoch: 7/100. Step 73/100. Loss: 6.24. Err: 27.68cm
# Epoch: 7/100. Step 74/100. Loss: 6.24. Err: 27.53cm
# Epoch: 7/100. Step 75/100. Loss: 6.24. Err: 27.84cm
# Epoch: 7/100. Step 76/100. Loss: 6.24. Err: 27.48cm
# Epoch: 7/100. Step 77/100. Loss: 6.24. Err: 27.65cm
# Epoch: 7/100. Step 78/100. Loss: 6.24. Err: 27.74cm
# Epoch: 7/100. Step 79/100. Loss: 6.24. Err: 27.5cm
# Epoch: 7/100. Step 80/100. Loss: 6.24. Err: 27.67cm
# Epoch: 7/100. Step 81/100. Loss: 6.24. Err: 27.75cm
# Epoch: 7/100. Step 82/100. Loss: 6.24. Err: 27.72cm
# Epoch: 7/100. Step 83/100. Loss: 6.24. Err: 27.76cm
# Epoch: 7/100. Step 84/100. Loss: 6.24. Err: 27.75cm
# Epoch: 7/100. Step 85/100. Loss: 6.24. Err: 27.57cm
# Epoch: 7/100. Step 86/100. Loss: 6.24. Err: 27.76cm
# Epoch: 7/100. Step 87/100. Loss: 6.24. Err: 27.65cm
# Epoch: 7/100. Step 88/100. Loss: 6.24. Err: 27.71cm
# Epoch: 7/100. Step 89/100. Loss: 6.24. Err: 27.51cm
# Epoch: 7/100. Step 90/100. Loss: 6.24. Err: 27.53cm
# Epoch: 7/100. Step 91/100. Loss: 6.24. Err: 27.74cm
# Epoch: 7/100. Step 92/100. Loss: 6.24. Err: 27.62cm
# Epoch: 7/100. Step 93/100. Loss: 6.24. Err: 27.66cm
# Epoch: 7/100. Step 94/100. Loss: 6.24. Err: 27.77cm
# Epoch: 7/100. Step 95/100. Loss: 6.24. Err: 28.04cm
# Epoch: 7/100. Step 96/100. Loss: 6.24. Err: 27.77cm
# Epoch: 7/100. Step 97/100. Loss: 6.24. Err: 27.58cm
# Epoch: 7/100. Step 98/100. Loss: 6.24. Err: 27.94cm
# Epoch: 7/100. Step 99/100. Loss: 6.24. Err: 27.72cm
# Epoch: 8/100. Step 0/100. Loss: 6.24. Err: 27.78cm
# Epoch: 8/100. Step 1/100. Loss: 6.24. Err: 27.68cm
# Epoch: 8/100. Step 2/100. Loss: 6.24. Err: 27.81cm
# Epoch: 8/100. Step 3/100. Loss: 6.24. Err: 27.7cm
# Epoch: 8/100. Step 4/100. Loss: 6.24. Err: 27.86cm
# Epoch: 8/100. Step 5/100. Loss: 6.24. Err: 27.98cm
# Epoch: 8/100. Step 6/100. Loss: 6.24. Err: 27.72cm
# Epoch: 8/100. Step 7/100. Loss: 6.24. Err: 27.63cm
# Epoch: 8/100. Step 8/100. Loss: 6.24. Err: 27.56cm
# Epoch: 8/100. Step 9/100. Loss: 6.24. Err: 27.81cm
# Epoch: 8/100. Step 10/100. Loss: 6.24. Err: 27.73cm
# Epoch: 8/100. Step 11/100. Loss: 6.24. Err: 27.77cm
# Epoch: 8/100. Step 12/100. Loss: 6.24. Err: 27.55cm
# Epoch: 8/100. Step 13/100. Loss: 6.24. Err: 27.75cm
# Epoch: 8/100. Step 14/100. Loss: 6.24. Err: 27.38cm
# Epoch: 8/100. Step 15/100. Loss: 6.24. Err: 27.67cm
# Epoch: 8/100. Step 16/100. Loss: 6.24. Err: 27.64cm
# Epoch: 8/100. Step 17/100. Loss: 6.24. Err: 27.76cm
# Epoch: 8/100. Step 18/100. Loss: 6.24. Err: 27.86cm
# Epoch: 8/100. Step 19/100. Loss: 6.24. Err: 27.59cm
# Epoch: 8/100. Step 20/100. Loss: 6.24. Err: 27.55cm
# Epoch: 8/100. Step 21/100. Loss: 6.24. Err: 27.73cm
# Epoch: 8/100. Step 22/100. Loss: 6.24. Err: 27.66cm
# Epoch: 8/100. Step 23/100. Loss: 6.24. Err: 27.69cm
# Epoch: 8/100. Step 24/100. Loss: 6.24. Err: 27.68cm
# Epoch: 8/100. Step 25/100. Loss: 6.24. Err: 27.76cm
# Epoch: 8/100. Step 26/100. Loss: 6.24. Err: 27.51cm
# Epoch: 8/100. Step 27/100. Loss: 6.24. Err: 27.78cm
# Epoch: 8/100. Step 28/100. Loss: 6.24. Err: 27.79cm
# Epoch: 8/100. Step 29/100. Loss: 6.24. Err: 27.64cm
# Epoch: 8/100. Step 30/100. Loss: 6.24. Err: 27.72cm
# Epoch: 8/100. Step 31/100. Loss: 6.24. Err: 27.55cm
# Epoch: 8/100. Step 32/100. Loss: 6.24. Err: 27.55cm
# Epoch: 8/100. Step 33/100. Loss: 6.24. Err: 27.84cm
# Epoch: 8/100. Step 34/100. Loss: 6.24. Err: 27.59cm
# Epoch: 8/100. Step 35/100. Loss: 6.24. Err: 27.72cm
# Epoch: 8/100. Step 36/100. Loss: 6.24. Err: 27.56cm
# Epoch: 8/100. Step 37/100. Loss: 6.24. Err: 27.72cm
# Epoch: 8/100. Step 38/100. Loss: 6.24. Err: 27.64cm
# Epoch: 8/100. Step 39/100. Loss: 6.24. Err: 27.63cm
# Epoch: 8/100. Step 40/100. Loss: 6.24. Err: 27.43cm
# Epoch: 8/100. Step 41/100. Loss: 6.24. Err: 27.53cm
# Epoch: 8/100. Step 42/100. Loss: 6.24. Err: 27.41cm
# Epoch: 8/100. Step 43/100. Loss: 6.24. Err: 27.62cm
# Epoch: 8/100. Step 44/100. Loss: 6.24. Err: 27.52cm
# Epoch: 8/100. Step 45/100. Loss: 6.24. Err: 27.64cm
# Epoch: 8/100. Step 46/100. Loss: 6.24. Err: 27.71cm
# Epoch: 8/100. Step 47/100. Loss: 6.24. Err: 27.63cm
# Epoch: 8/100. Step 48/100. Loss: 6.24. Err: 27.55cm
# Epoch: 8/100. Step 49/100. Loss: 6.24. Err: 27.65cm
# Epoch: 8/100. Step 50/100. Loss: 6.24. Err: 27.57cm
# Epoch: 8/100. Step 51/100. Loss: 6.24. Err: 27.47cm
# Epoch: 8/100. Step 52/100. Loss: 6.24. Err: 27.69cm
# Epoch: 8/100. Step 53/100. Loss: 6.24. Err: 27.6cm
# Epoch: 8/100. Step 54/100. Loss: 6.24. Err: 27.67cm
# Epoch: 8/100. Step 55/100. Loss: 6.24. Err: 27.51cm
# Epoch: 8/100. Step 56/100. Loss: 6.24. Err: 27.73cm
# Epoch: 8/100. Step 57/100. Loss: 6.24. Err: 27.6cm
# Epoch: 8/100. Step 58/100. Loss: 6.24. Err: 27.8cm
# Epoch: 8/100. Step 59/100. Loss: 6.24. Err: 27.71cm
# Epoch: 8/100. Step 60/100. Loss: 6.24. Err: 27.73cm
# Epoch: 8/100. Step 61/100. Loss: 6.24. Err: 27.84cm
# Epoch: 8/100. Step 62/100. Loss: 6.24. Err: 27.53cm
# Epoch: 8/100. Step 63/100. Loss: 6.24. Err: 27.63cm
# Epoch: 8/100. Step 64/100. Loss: 6.24. Err: 27.7cm
# Epoch: 8/100. Step 65/100. Loss: 6.24. Err: 27.51cm
# Epoch: 8/100. Step 66/100. Loss: 6.24. Err: 27.64cm
# Epoch: 8/100. Step 67/100. Loss: 6.24. Err: 27.59cm
# Epoch: 8/100. Step 68/100. Loss: 6.24. Err: 27.67cm
# Epoch: 8/100. Step 69/100. Loss: 6.24. Err: 27.74cm
# Epoch: 8/100. Step 70/100. Loss: 6.24. Err: 27.86cm
# Epoch: 8/100. Step 71/100. Loss: 6.24. Err: 27.68cm
# Epoch: 8/100. Step 72/100. Loss: 6.24. Err: 27.71cm
# Epoch: 8/100. Step 73/100. Loss: 6.24. Err: 27.78cm
# Epoch: 8/100. Step 74/100. Loss: 6.24. Err: 27.71cm
# Epoch: 8/100. Step 75/100. Loss: 6.24. Err: 27.62cm
# Epoch: 8/100. Step 76/100. Loss: 6.24. Err: 27.71cm
# Epoch: 8/100. Step 77/100. Loss: 6.24. Err: 27.8cm
# Epoch: 8/100. Step 78/100. Loss: 6.24. Err: 27.6cm
# Epoch: 8/100. Step 79/100. Loss: 6.24. Err: 27.79cm
# Epoch: 8/100. Step 80/100. Loss: 6.24. Err: 27.7cm
# Epoch: 8/100. Step 81/100. Loss: 6.24. Err: 27.7cm
# Epoch: 8/100. Step 82/100. Loss: 6.24. Err: 27.56cm
# Epoch: 8/100. Step 83/100. Loss: 6.24. Err: 27.71cm
# Epoch: 8/100. Step 84/100. Loss: 6.24. Err: 27.98cm
# Epoch: 8/100. Step 85/100. Loss: 6.24. Err: 27.75cm
# Epoch: 8/100. Step 86/100. Loss: 6.24. Err: 27.84cm
# Epoch: 8/100. Step 87/100. Loss: 6.24. Err: 28.08cm
# Epoch: 8/100. Step 88/100. Loss: 6.24. Err: 27.63cm
# Epoch: 8/100. Step 89/100. Loss: 6.24. Err: 27.78cm
# Epoch: 8/100. Step 90/100. Loss: 6.24. Err: 27.76cm
# Epoch: 8/100. Step 91/100. Loss: 6.24. Err: 27.76cm
# Epoch: 8/100. Step 92/100. Loss: 6.24. Err: 27.68cm
# Epoch: 8/100. Step 93/100. Loss: 6.24. Err: 27.91cm
# Epoch: 8/100. Step 94/100. Loss: 6.24. Err: 28.13cm
# Epoch: 8/100. Step 95/100. Loss: 6.24. Err: 28.01cm
# Epoch: 8/100. Step 96/100. Loss: 6.24. Err: 28.06cm
# Epoch: 8/100. Step 97/100. Loss: 6.24. Err: 27.93cm
# Epoch: 8/100. Step 98/100. Loss: 6.24. Err: 27.86cm
# Epoch: 8/100. Step 99/100. Loss: 6.24. Err: 27.95cm
# Epoch: 9/100. Step 0/100. Loss: 6.24. Err: 28.08cm
# Epoch: 9/100. Step 1/100. Loss: 6.24. Err: 28.02cm
# Epoch: 9/100. Step 2/100. Loss: 6.24. Err: 27.99cm
# Epoch: 9/100. Step 3/100. Loss: 6.24. Err: 27.95cm
# Epoch: 9/100. Step 4/100. Loss: 6.24. Err: 28.08cm
# Epoch: 9/100. Step 5/100. Loss: 6.24. Err: 27.91cm
# Epoch: 9/100. Step 6/100. Loss: 6.24. Err: 28.18cm
# Epoch: 9/100. Step 7/100. Loss: 6.24. Err: 28.1cm
# Epoch: 9/100. Step 8/100. Loss: 6.24. Err: 28.11cm
# Epoch: 9/100. Step 9/100. Loss: 6.24. Err: 28.05cm
# Epoch: 9/100. Step 10/100. Loss: 6.24. Err: 28.0cm
# Epoch: 9/100. Step 11/100. Loss: 6.24. Err: 27.92cm
# Epoch: 9/100. Step 12/100. Loss: 6.24. Err: 28.03cm
# Epoch: 9/100. Step 13/100. Loss: 6.24. Err: 27.98cm
# Epoch: 9/100. Step 14/100. Loss: 6.24. Err: 28.17cm
# Epoch: 9/100. Step 15/100. Loss: 6.24. Err: 28.0cm
# Epoch: 9/100. Step 16/100. Loss: 6.24. Err: 28.08cm
# Epoch: 9/100. Step 17/100. Loss: 6.24. Err: 28.03cm
# Epoch: 9/100. Step 18/100. Loss: 6.24. Err: 27.86cm
# Epoch: 9/100. Step 19/100. Loss: 6.24. Err: 28.12cm
# Epoch: 9/100. Step 20/100. Loss: 6.24. Err: 27.95cm
# Epoch: 9/100. Step 21/100. Loss: 6.24. Err: 27.98cm
# Epoch: 9/100. Step 22/100. Loss: 6.24. Err: 27.94cm
# Epoch: 9/100. Step 23/100. Loss: 6.24. Err: 28.05cm
# Epoch: 9/100. Step 24/100. Loss: 6.24. Err: 28.11cm
# Epoch: 9/100. Step 25/100. Loss: 6.24. Err: 28.25cm
# Epoch: 9/100. Step 26/100. Loss: 6.24. Err: 27.94cm
# Epoch: 9/100. Step 27/100. Loss: 6.24. Err: 27.98cm
# Epoch: 9/100. Step 28/100. Loss: 6.24. Err: 27.91cm
# Epoch: 9/100. Step 29/100. Loss: 6.24. Err: 27.94cm
# Epoch: 9/100. Step 30/100. Loss: 6.24. Err: 28.07cm
# Epoch: 9/100. Step 31/100. Loss: 6.24. Err: 27.9cm
# Epoch: 9/100. Step 32/100. Loss: 6.24. Err: 28.29cm
# Epoch: 9/100. Step 33/100. Loss: 6.24. Err: 28.07cm
# Epoch: 9/100. Step 34/100. Loss: 6.24. Err: 27.96cm
# Epoch: 9/100. Step 35/100. Loss: 6.24. Err: 28.28cm
# Epoch: 9/100. Step 36/100. Loss: 6.24. Err: 28.13cm
# Epoch: 9/100. Step 37/100. Loss: 6.24. Err: 28.01cm
# Epoch: 9/100. Step 38/100. Loss: 6.24. Err: 28.12cm
# Epoch: 9/100. Step 39/100. Loss: 6.24. Err: 28.18cm
# Epoch: 9/100. Step 40/100. Loss: 6.24. Err: 28.17cm
# Epoch: 9/100. Step 41/100. Loss: 6.24. Err: 28.18cm
# Epoch: 9/100. Step 42/100. Loss: 6.24. Err: 28.02cm
# Epoch: 9/100. Step 43/100. Loss: 6.24. Err: 28.16cm
# Epoch: 9/100. Step 44/100. Loss: 6.24. Err: 28.29cm
# Epoch: 9/100. Step 45/100. Loss: 6.24. Err: 28.19cm
# Epoch: 9/100. Step 46/100. Loss: 6.24. Err: 28.2cm
# Epoch: 9/100. Step 47/100. Loss: 6.24. Err: 28.13cm
# Epoch: 9/100. Step 48/100. Loss: 6.24. Err: 28.11cm
# Epoch: 9/100. Step 49/100. Loss: 6.24. Err: 28.22cm
# Epoch: 9/100. Step 50/100. Loss: 6.24. Err: 28.12cm
# Epoch: 9/100. Step 51/100. Loss: 6.24. Err: 27.94cm
# Epoch: 9/100. Step 52/100. Loss: 6.24. Err: 27.96cm
# Epoch: 9/100. Step 53/100. Loss: 6.24. Err: 28.24cm
# Epoch: 9/100. Step 54/100. Loss: 6.24. Err: 28.16cm
# Epoch: 9/100. Step 55/100. Loss: 6.24. Err: 28.21cm
# Epoch: 9/100. Step 56/100. Loss: 6.24. Err: 28.2cm
# Epoch: 9/100. Step 57/100. Loss: 6.24. Err: 28.16cm
# Epoch: 9/100. Step 58/100. Loss: 6.24. Err: 28.37cm
# Epoch: 9/100. Step 59/100. Loss: 6.24. Err: 28.23cm
# Epoch: 9/100. Step 60/100. Loss: 6.24. Err: 28.29cm
# Epoch: 9/100. Step 61/100. Loss: 6.24. Err: 28.27cm
# Epoch: 9/100. Step 62/100. Loss: 6.24. Err: 28.17cm
# Epoch: 9/100. Step 63/100. Loss: 6.24. Err: 28.04cm
# Epoch: 9/100. Step 64/100. Loss: 6.24. Err: 28.24cm
# Epoch: 9/100. Step 65/100. Loss: 6.24. Err: 28.15cm
# Epoch: 9/100. Step 66/100. Loss: 6.24. Err: 28.24cm
# Epoch: 9/100. Step 67/100. Loss: 6.24. Err: 28.26cm
# Epoch: 9/100. Step 68/100. Loss: 6.24. Err: 28.27cm
# Epoch: 9/100. Step 69/100. Loss: 6.24. Err: 28.29cm
# Epoch: 9/100. Step 70/100. Loss: 6.24. Err: 28.1cm
# Epoch: 9/100. Step 71/100. Loss: 6.24. Err: 28.08cm
# Epoch: 9/100. Step 72/100. Loss: 6.24. Err: 28.06cm
# Epoch: 9/100. Step 73/100. Loss: 6.24. Err: 28.38cm
# Epoch: 9/100. Step 74/100. Loss: 6.24. Err: 28.16cm
# Epoch: 9/100. Step 75/100. Loss: 6.24. Err: 28.25cm
# Epoch: 9/100. Step 76/100. Loss: 6.24. Err: 28.15cm
# Epoch: 9/100. Step 77/100. Loss: 6.24. Err: 28.31cm
# Epoch: 9/100. Step 78/100. Loss: 6.24. Err: 28.3cm
# Epoch: 9/100. Step 79/100. Loss: 6.24. Err: 28.35cm
# Epoch: 9/100. Step 80/100. Loss: 6.24. Err: 28.43cm
# Epoch: 9/100. Step 81/100. Loss: 6.24. Err: 28.34cm
# Epoch: 9/100. Step 82/100. Loss: 6.24. Err: 28.45cm
# Epoch: 9/100. Step 83/100. Loss: 6.24. Err: 28.16cm
# Epoch: 9/100. Step 84/100. Loss: 6.24. Err: 28.48cm
# Epoch: 9/100. Step 85/100. Loss: 6.24. Err: 28.09cm
# Epoch: 9/100. Step 86/100. Loss: 6.24. Err: 28.1cm
# Epoch: 9/100. Step 87/100. Loss: 6.24. Err: 28.3cm
# Epoch: 9/100. Step 88/100. Loss: 6.24. Err: 28.38cm
# Epoch: 9/100. Step 89/100. Loss: 6.24. Err: 28.26cm
# Epoch: 9/100. Step 90/100. Loss: 6.24. Err: 28.43cm
# Epoch: 9/100. Step 91/100. Loss: 6.24. Err: 28.55cm
# Epoch: 9/100. Step 92/100. Loss: 6.24. Err: 28.83cm
# Epoch: 9/100. Step 93/100. Loss: 6.24. Err: 28.47cm
# Epoch: 9/100. Step 94/100. Loss: 6.24. Err: 28.52cm
# Epoch: 9/100. Step 95/100. Loss: 6.24. Err: 28.36cm
# Epoch: 9/100. Step 96/100. Loss: 6.24. Err: 28.47cm
# Epoch: 9/100. Step 97/100. Loss: 6.24. Err: 28.24cm
# Epoch: 9/100. Step 98/100. Loss: 6.24. Err: 28.51cm
# Epoch: 9/100. Step 99/100. Loss: 6.24. Err: 28.51cm
# Epoch: 10/100. Step 0/100. Loss: 6.24. Err: 28.31cm
# Epoch: 10/100. Step 1/100. Loss: 6.24. Err: 28.43cm
# Epoch: 10/100. Step 2/100. Loss: 6.24. Err: 28.44cm
# Epoch: 10/100. Step 3/100. Loss: 6.24. Err: 28.44cm
# Epoch: 10/100. Step 4/100. Loss: 6.24. Err: 28.45cm
# Epoch: 10/100. Step 5/100. Loss: 6.24. Err: 28.44cm
# Epoch: 10/100. Step 6/100. Loss: 6.24. Err: 28.67cm
# Epoch: 10/100. Step 7/100. Loss: 6.24. Err: 28.37cm
# Epoch: 10/100. Step 8/100. Loss: 6.24. Err: 28.35cm
# Epoch: 10/100. Step 9/100. Loss: 6.24. Err: 28.63cm
# Epoch: 10/100. Step 10/100. Loss: 6.24. Err: 28.55cm
# Epoch: 10/100. Step 11/100. Loss: 6.24. Err: 28.57cm
# Epoch: 10/100. Step 12/100. Loss: 6.24. Err: 28.45cm
# Epoch: 10/100. Step 13/100. Loss: 6.24. Err: 28.46cm
# Epoch: 10/100. Step 14/100. Loss: 6.24. Err: 28.46cm
# Epoch: 10/100. Step 15/100. Loss: 6.24. Err: 28.55cm
# Epoch: 10/100. Step 16/100. Loss: 6.24. Err: 28.64cm
# Epoch: 10/100. Step 17/100. Loss: 6.24. Err: 28.51cm
# Epoch: 10/100. Step 18/100. Loss: 6.24. Err: 28.54cm
# Epoch: 10/100. Step 19/100. Loss: 6.24. Err: 28.37cm
# Epoch: 10/100. Step 20/100. Loss: 6.24. Err: 28.67cm
# Epoch: 10/100. Step 21/100. Loss: 6.24. Err: 28.75cm
# Epoch: 10/100. Step 22/100. Loss: 6.24. Err: 28.37cm
# Epoch: 10/100. Step 23/100. Loss: 6.24. Err: 28.36cm
# Epoch: 10/100. Step 24/100. Loss: 6.24. Err: 28.52cm
# Epoch: 10/100. Step 25/100. Loss: 6.24. Err: 28.39cm
# ...
# Epoch: 97/100. Step 94/100. Loss: 6.22. Err: 9.32cm
# Epoch: 97/100. Step 95/100. Loss: 6.22. Err: 9.75cm
# Epoch: 97/100. Step 96/100. Loss: 6.22. Err: 9.43cm
# Epoch: 97/100. Step 97/100. Loss: 6.22. Err: 9.21cm
# Epoch: 97/100. Step 98/100. Loss: 6.22. Err: 9.28cm
# Epoch: 97/100. Step 99/100. Loss: 6.22. Err: 9.31cm
# Epoch: 98/100. Step 0/100. Loss: 6.22. Err: 9.0cm
# Epoch: 98/100. Step 1/100. Loss: 6.23. Err: 9.48cm
# Epoch: 98/100. Step 2/100. Loss: 6.23. Err: 10.7cm
# Epoch: 98/100. Step 3/100. Loss: 6.22. Err: 9.11cm
# Epoch: 98/100. Step 4/100. Loss: 6.22. Err: 9.95cm
# Epoch: 98/100. Step 5/100. Loss: 6.22. Err: 9.72cm
# Epoch: 98/100. Step 6/100. Loss: 6.22. Err: 9.51cm
# Epoch: 98/100. Step 7/100. Loss: 6.23. Err: 10.37cm
# Epoch: 98/100. Step 8/100. Loss: 6.22. Err: 9.32cm
# Epoch: 98/100. Step 9/100. Loss: 6.23. Err: 10.84cm
# Epoch: 98/100. Step 10/100. Loss: 6.22. Err: 9.4cm
# Epoch: 98/100. Step 11/100. Loss: 6.22. Err: 10.02cm
# Epoch: 98/100. Step 12/100. Loss: 6.23. Err: 10.76cm
# Epoch: 98/100. Step 13/100. Loss: 6.22. Err: 9.75cm
# Epoch: 98/100. Step 14/100. Loss: 6.23. Err: 10.64cm
# Epoch: 98/100. Step 15/100. Loss: 6.22. Err: 9.34cm
# Epoch: 98/100. Step 16/100. Loss: 6.23. Err: 10.86cm
# Epoch: 98/100. Step 17/100. Loss: 6.23. Err: 9.45cm
# Epoch: 98/100. Step 18/100. Loss: 6.23. Err: 10.29cm
# Epoch: 98/100. Step 19/100. Loss: 6.22. Err: 9.31cm
# Epoch: 98/100. Step 20/100. Loss: 6.22. Err: 10.05cm
# Epoch: 98/100. Step 21/100. Loss: 6.22. Err: 9.19cm
# Epoch: 98/100. Step 22/100. Loss: 6.22. Err: 9.54cm
# Epoch: 98/100. Step 23/100. Loss: 6.22. Err: 8.96cm
# Epoch: 98/100. Step 24/100. Loss: 6.22. Err: 9.31cm
# Epoch: 98/100. Step 25/100. Loss: 6.22. Err: 8.83cm
# Epoch: 98/100. Step 26/100. Loss: 6.22. Err: 9.15cm
# Epoch: 98/100. Step 27/100. Loss: 6.22. Err: 9.38cm
# Epoch: 98/100. Step 28/100. Loss: 6.22. Err: 8.87cm
# Epoch: 98/100. Step 29/100. Loss: 6.22. Err: 9.25cm
# Epoch: 98/100. Step 30/100. Loss: 6.22. Err: 8.9cm
# Epoch: 98/100. Step 31/100. Loss: 6.22. Err: 9.05cm
# Epoch: 98/100. Step 32/100. Loss: 6.22. Err: 8.79cm
# Epoch: 98/100. Step 33/100. Loss: 6.22. Err: 9.04cm
# Epoch: 98/100. Step 34/100. Loss: 6.22. Err: 8.96cm
# Epoch: 98/100. Step 35/100. Loss: 6.22. Err: 8.77cm
# Epoch: 98/100. Step 36/100. Loss: 6.22. Err: 8.9cm
# Epoch: 98/100. Step 37/100. Loss: 6.22. Err: 8.76cm
# Epoch: 98/100. Step 38/100. Loss: 6.22. Err: 8.61cm
# Epoch: 98/100. Step 39/100. Loss: 6.22. Err: 8.73cm
# Epoch: 98/100. Step 40/100. Loss: 6.22. Err: 8.79cm
# Epoch: 98/100. Step 41/100. Loss: 6.22. Err: 8.68cm
# Epoch: 98/100. Step 42/100. Loss: 6.22. Err: 8.7cm
# Epoch: 98/100. Step 43/100. Loss: 6.22. Err: 9.02cm
# Epoch: 98/100. Step 44/100. Loss: 6.23. Err: 8.86cm
# Epoch: 98/100. Step 45/100. Loss: 6.23. Err: 8.72cm
# Epoch: 98/100. Step 46/100. Loss: 6.22. Err: 8.71cm
# Epoch: 98/100. Step 47/100. Loss: 6.22. Err: 8.87cm
# Epoch: 98/100. Step 48/100. Loss: 6.22. Err: 9.15cm
# Epoch: 98/100. Step 49/100. Loss: 6.22. Err: 9.01cm
# Epoch: 98/100. Step 50/100. Loss: 6.22. Err: 8.63cm
# Epoch: 98/100. Step 51/100. Loss: 6.22. Err: 8.63cm
# Epoch: 98/100. Step 52/100. Loss: 6.22. Err: 9.08cm
# Epoch: 98/100. Step 53/100. Loss: 6.22. Err: 9.08cm
# Epoch: 98/100. Step 54/100. Loss: 6.22. Err: 8.63cm
# Epoch: 98/100. Step 55/100. Loss: 6.22. Err: 8.65cm
# Epoch: 98/100. Step 56/100. Loss: 6.22. Err: 8.64cm
# Epoch: 98/100. Step 57/100. Loss: 6.22. Err: 8.57cm
# Epoch: 98/100. Step 58/100. Loss: 6.22. Err: 8.69cm
# Epoch: 98/100. Step 59/100. Loss: 6.22. Err: 8.82cm
# Epoch: 98/100. Step 60/100. Loss: 6.22. Err: 8.58cm
# Epoch: 98/100. Step 61/100. Loss: 6.22. Err: 8.57cm
# Epoch: 98/100. Step 62/100. Loss: 6.22. Err: 8.58cm
# Epoch: 98/100. Step 63/100. Loss: 6.22. Err: 8.65cm
# Epoch: 98/100. Step 64/100. Loss: 6.22. Err: 8.52cm
# Epoch: 98/100. Step 65/100. Loss: 6.22. Err: 8.46cm
# Epoch: 98/100. Step 66/100. Loss: 6.22. Err: 8.55cm
# Epoch: 98/100. Step 67/100. Loss: 6.22. Err: 8.53cm
# Epoch: 98/100. Step 68/100. Loss: 6.22. Err: 8.86cm
# Epoch: 98/100. Step 69/100. Loss: 6.22. Err: 9.11cm
# Epoch: 98/100. Step 70/100. Loss: 6.22. Err: 8.76cm
# Epoch: 98/100. Step 71/100. Loss: 6.22. Err: 8.52cm
# Epoch: 98/100. Step 72/100. Loss: 6.22. Err: 8.71cm
# Epoch: 98/100. Step 73/100. Loss: 6.22. Err: 8.71cm
# Epoch: 98/100. Step 74/100. Loss: 6.22. Err: 9.41cm
# Epoch: 98/100. Step 75/100. Loss: 6.22. Err: 8.51cm
# Epoch: 98/100. Step 76/100. Loss: 6.22. Err: 8.44cm
# Epoch: 98/100. Step 77/100. Loss: 6.22. Err: 9.14cm
# Epoch: 98/100. Step 78/100. Loss: 6.22. Err: 9.47cm
# Epoch: 98/100. Step 79/100. Loss: 6.22. Err: 8.7cm
# Epoch: 98/100. Step 80/100. Loss: 6.22. Err: 9.06cm
# Epoch: 98/100. Step 81/100. Loss: 6.22. Err: 8.7cm
# Epoch: 98/100. Step 82/100. Loss: 6.22. Err: 8.62cm
# Epoch: 98/100. Step 83/100. Loss: 6.22. Err: 8.52cm
# Epoch: 98/100. Step 84/100. Loss: 6.22. Err: 8.87cm
# Epoch: 98/100. Step 85/100. Loss: 6.22. Err: 8.67cm
# Epoch: 98/100. Step 86/100. Loss: 6.22. Err: 8.62cm
# Epoch: 98/100. Step 87/100. Loss: 6.22. Err: 8.43cm
# Epoch: 98/100. Step 88/100. Loss: 6.22. Err: 8.51cm
# Epoch: 98/100. Step 89/100. Loss: 6.22. Err: 8.35cm
# Epoch: 98/100. Step 90/100. Loss: 6.22. Err: 8.51cm
# Epoch: 98/100. Step 91/100. Loss: 6.22. Err: 8.27cm
# Epoch: 98/100. Step 92/100. Loss: 6.22. Err: 8.4cm
# Epoch: 98/100. Step 93/100. Loss: 6.22. Err: 8.33cm
# Epoch: 98/100. Step 94/100. Loss: 6.22. Err: 8.4cm
# Epoch: 98/100. Step 95/100. Loss: 6.22. Err: 8.23cm
# Epoch: 98/100. Step 96/100. Loss: 6.22. Err: 8.36cm
# Epoch: 98/100. Step 97/100. Loss: 6.22. Err: 8.38cm
# Epoch: 98/100. Step 98/100. Loss: 6.22. Err: 8.53cm
# Epoch: 98/100. Step 99/100. Loss: 6.22. Err: 8.08cm
# Epoch: 99/100. Step 0/100. Loss: 6.22. Err: 8.42cm
# Epoch: 99/100. Step 1/100. Loss: 6.22. Err: 8.18cm
# Epoch: 99/100. Step 2/100. Loss: 6.22. Err: 8.42cm
# Epoch: 99/100. Step 3/100. Loss: 6.22. Err: 8.01cm
# Epoch: 99/100. Step 4/100. Loss: 6.22. Err: 8.26cm
# Epoch: 99/100. Step 5/100. Loss: 6.22. Err: 8.0cm
# Epoch: 99/100. Step 6/100. Loss: 6.22. Err: 8.45cm
# Epoch: 99/100. Step 7/100. Loss: 6.22. Err: 8.64cm
# Epoch: 99/100. Step 8/100. Loss: 6.22. Err: 8.29cm
# Epoch: 99/100. Step 9/100. Loss: 6.22. Err: 8.31cm
# Epoch: 99/100. Step 10/100. Loss: 6.22. Err: 8.28cm
# Epoch: 99/100. Step 11/100. Loss: 6.22. Err: 8.25cm
# Epoch: 99/100. Step 12/100. Loss: 6.22. Err: 8.6cm
# Epoch: 99/100. Step 13/100. Loss: 6.22. Err: 8.13cm
# Epoch: 99/100. Step 14/100. Loss: 6.22. Err: 8.44cm
# Epoch: 99/100. Step 15/100. Loss: 6.22. Err: 8.12cm
# Epoch: 99/100. Step 16/100. Loss: 6.22. Err: 8.06cm
# Epoch: 99/100. Step 17/100. Loss: 6.22. Err: 8.33cm
# Epoch: 99/100. Step 18/100. Loss: 6.22. Err: 8.54cm
# Epoch: 99/100. Step 19/100. Loss: 6.22. Err: 8.48cm
# Epoch: 99/100. Step 20/100. Loss: 6.22. Err: 8.21cm
# Epoch: 99/100. Step 21/100. Loss: 6.22. Err: 8.33cm
# Epoch: 99/100. Step 22/100. Loss: 6.22. Err: 8.55cm
# Epoch: 99/100. Step 23/100. Loss: 6.22. Err: 8.07cm
# Epoch: 99/100. Step 24/100. Loss: 6.22. Err: 8.14cm
# Epoch: 99/100. Step 25/100. Loss: 6.22. Err: 8.17cm
# Epoch: 99/100. Step 26/100. Loss: 6.22. Err: 8.25cm
# Epoch: 99/100. Step 27/100. Loss: 6.22. Err: 8.07cm
# Epoch: 99/100. Step 28/100. Loss: 6.22. Err: 8.02cm
# Epoch: 99/100. Step 29/100. Loss: 6.22. Err: 8.0cm
# Epoch: 99/100. Step 30/100. Loss: 6.22. Err: 8.07cm
# Epoch: 99/100. Step 31/100. Loss: 6.22. Err: 7.86cm
# Epoch: 99/100. Step 32/100. Loss: 6.22. Err: 7.95cm
# Epoch: 99/100. Step 33/100. Loss: 6.22. Err: 7.89cm
# Epoch: 99/100. Step 34/100. Loss: 6.22. Err: 7.95cm
# Epoch: 99/100. Step 35/100. Loss: 6.22. Err: 7.74cm
# Epoch: 99/100. Step 36/100. Loss: 6.22. Err: 7.72cm
# Epoch: 99/100. Step 37/100. Loss: 6.22. Err: 7.78cm
# Epoch: 99/100. Step 38/100. Loss: 6.22. Err: 8.11cm
# Epoch: 99/100. Step 39/100. Loss: 6.22. Err: 8.16cm
# Epoch: 99/100. Step 40/100. Loss: 6.22. Err: 7.93cm
# Epoch: 99/100. Step 41/100. Loss: 6.22. Err: 7.81cm
# Epoch: 99/100. Step 42/100. Loss: 6.22. Err: 7.83cm
# Epoch: 99/100. Step 43/100. Loss: 6.22. Err: 8.19cm
# Epoch: 99/100. Step 44/100. Loss: 6.22. Err: 8.1cm
# Epoch: 99/100. Step 45/100. Loss: 6.22. Err: 7.69cm
# Epoch: 99/100. Step 46/100. Loss: 6.22. Err: 7.95cm
# Epoch: 99/100. Step 47/100. Loss: 6.22. Err: 8.57cm
# Epoch: 99/100. Step 48/100. Loss: 6.22. Err: 8.19cm
# Epoch: 99/100. Step 49/100. Loss: 6.22. Err: 7.99cm
# Epoch: 99/100. Step 50/100. Loss: 6.22. Err: 7.98cm
# Epoch: 99/100. Step 51/100. Loss: 6.23. Err: 9.0cm
# Epoch: 99/100. Step 52/100. Loss: 6.22. Err: 8.02cm
# Epoch: 99/100. Step 53/100. Loss: 6.22. Err: 8.63cm
# Epoch: 99/100. Step 54/100. Loss: 6.23. Err: 9.42cm
# Epoch: 99/100. Step 55/100. Loss: 6.22. Err: 8.54cm
# Epoch: 99/100. Step 56/100. Loss: 6.23. Err: 11.41cm
# Epoch: 99/100. Step 57/100. Loss: 6.22. Err: 8.17cm
# Epoch: 99/100. Step 58/100. Loss: 6.23. Err: 11.14cm
# Epoch: 99/100. Step 59/100. Loss: 6.22. Err: 8.28cm
# Epoch: 99/100. Step 60/100. Loss: 6.23. Err: 10.06cm
# Epoch: 99/100. Step 61/100. Loss: 6.22. Err: 8.54cm
# Epoch: 99/100. Step 62/100. Loss: 6.22. Err: 9.35cm
# Epoch: 99/100. Step 63/100. Loss: 6.22. Err: 8.05cm
# Epoch: 99/100. Step 64/100. Loss: 6.22. Err: 9.23cm
# Epoch: 99/100. Step 65/100. Loss: 6.22. Err: 7.86cm
# Epoch: 99/100. Step 66/100. Loss: 6.22. Err: 8.77cm
# Epoch: 99/100. Step 67/100. Loss: 6.22. Err: 7.71cm
# Epoch: 99/100. Step 68/100. Loss: 6.22. Err: 8.63cm
# Epoch: 99/100. Step 69/100. Loss: 6.22. Err: 7.84cm
# Epoch: 99/100. Step 70/100. Loss: 6.22. Err: 8.57cm
# Epoch: 99/100. Step 71/100. Loss: 6.22. Err: 7.99cm
# Epoch: 99/100. Step 72/100. Loss: 6.22. Err: 8.35cm
# Epoch: 99/100. Step 73/100. Loss: 6.22. Err: 8.02cm
# Epoch: 99/100. Step 74/100. Loss: 6.22. Err: 7.88cm
# Epoch: 99/100. Step 75/100. Loss: 6.22. Err: 7.91cm
# Epoch: 99/100. Step 76/100. Loss: 6.22. Err: 7.83cm
# Epoch: 99/100. Step 77/100. Loss: 6.22. Err: 8.12cm
# Epoch: 99/100. Step 78/100. Loss: 6.22. Err: 7.68cm
# Epoch: 99/100. Step 79/100. Loss: 6.22. Err: 8.29cm
# Epoch: 99/100. Step 80/100. Loss: 6.22. Err: 7.53cm
# Epoch: 99/100. Step 81/100. Loss: 6.22. Err: 7.97cm
# Epoch: 99/100. Step 82/100. Loss: 6.22. Err: 7.49cm
# Epoch: 99/100. Step 83/100. Loss: 6.22. Err: 7.88cm
# Epoch: 99/100. Step 84/100. Loss: 6.22. Err: 7.63cm
# Epoch: 99/100. Step 85/100. Loss: 6.22. Err: 7.53cm
# Epoch: 99/100. Step 86/100. Loss: 6.22. Err: 7.69cm
# Epoch: 99/100. Step 87/100. Loss: 6.22. Err: 7.65cm
# Epoch: 99/100. Step 88/100. Loss: 6.22. Err: 7.75cm
# Epoch: 99/100. Step 89/100. Loss: 6.22. Err: 7.58cm
# Epoch: 99/100. Step 90/100. Loss: 6.22. Err: 7.79cm
# Epoch: 99/100. Step 91/100. Loss: 6.22. Err: 7.69cm
# Epoch: 99/100. Step 92/100. Loss: 6.22. Err: 7.91cm
# Epoch: 99/100. Step 93/100. Loss: 6.22. Err: 8.3cm
# Epoch: 99/100. Step 94/100. Loss: 6.22. Err: 7.53cm
# Epoch: 99/100. Step 95/100. Loss: 6.22. Err: 8.5cm
# Epoch: 99/100. Step 96/100. Loss: 6.22. Err: 7.77cm
# Epoch: 99/100. Step 97/100. Loss: 6.22. Err: 8.08cm
# Epoch: 99/100. Step 98/100. Loss: 6.22. Err: 7.73cm
# Epoch: 99/100. Step 99/100. Loss: 6.22. Err: 7.61cm
# Epoch: 100/100. Step 0/100. Loss: 6.22. Err: 7.7cm
# Epoch: 100/100. Step 1/100. Loss: 6.22. Err: 8.06cm
# Epoch: 100/100. Step 2/100. Loss: 6.22. Err: 7.82cm
# Epoch: 100/100. Step 3/100. Loss: 6.22. Err: 7.46cm
# Epoch: 100/100. Step 4/100. Loss: 6.22. Err: 7.73cm
# Epoch: 100/100. Step 5/100. Loss: 6.22. Err: 7.25cm
# Epoch: 100/100. Step 6/100. Loss: 6.22. Err: 7.55cm
# Epoch: 100/100. Step 7/100. Loss: 6.22. Err: 7.29cm
# Epoch: 100/100. Step 8/100. Loss: 6.22. Err: 7.42cm
# Epoch: 100/100. Step 9/100. Loss: 6.22. Err: 7.06cm
# Epoch: 100/100. Step 10/100. Loss: 6.22. Err: 7.35cm
# Epoch: 100/100. Step 11/100. Loss: 6.22. Err: 7.26cm
# Epoch: 100/100. Step 12/100. Loss: 6.22. Err: 7.27cm
# Epoch: 100/100. Step 13/100. Loss: 6.22. Err: 7.12cm
# Epoch: 100/100. Step 14/100. Loss: 6.22. Err: 7.37cm
# Epoch: 100/100. Step 15/100. Loss: 6.22. Err: 7.8cm
# Epoch: 100/100. Step 16/100. Loss: 6.22. Err: 7.12cm
# Epoch: 100/100. Step 17/100. Loss: 6.22. Err: 7.31cm
# Epoch: 100/100. Step 18/100. Loss: 6.22. Err: 7.32cm
# Epoch: 100/100. Step 19/100. Loss: 6.22. Err: 7.68cm
# Epoch: 100/100. Step 20/100. Loss: 6.22. Err: 7.23cm
# Epoch: 100/100. Step 21/100. Loss: 6.22. Err: 7.66cm
# Epoch: 100/100. Step 22/100. Loss: 6.22. Err: 8.04cm
# Epoch: 100/100. Step 23/100. Loss: 6.22. Err: 7.16cm
# Epoch: 100/100. Step 24/100. Loss: 6.22. Err: 7.92cm
# Epoch: 100/100. Step 25/100. Loss: 6.22. Err: 7.31cm
# Epoch: 100/100. Step 26/100. Loss: 6.22. Err: 8.06cm
# Epoch: 100/100. Step 27/100. Loss: 6.22. Err: 8.08cm
# Epoch: 100/100. Step 28/100. Loss: 6.22. Err: 8.04cm
# Epoch: 100/100. Step 29/100. Loss: 6.22. Err: 7.85cm
# Epoch: 100/100. Step 30/100. Loss: 6.22. Err: 7.44cm
# Epoch: 100/100. Step 31/100. Loss: 6.22. Err: 8.27cm
# Epoch: 100/100. Step 32/100. Loss: 6.22. Err: 7.16cm
# Epoch: 100/100. Step 33/100. Loss: 6.22. Err: 7.78cm
# Epoch: 100/100. Step 34/100. Loss: 6.22. Err: 7.04cm
# Epoch: 100/100. Step 35/100. Loss: 6.22. Err: 7.39cm
# Epoch: 100/100. Step 36/100. Loss: 6.22. Err: 7.19cm
# Epoch: 100/100. Step 37/100. Loss: 6.22. Err: 7.64cm
# Epoch: 100/100. Step 38/100. Loss: 6.22. Err: 7.16cm
# Epoch: 100/100. Step 39/100. Loss: 6.22. Err: 7.22cm
# Epoch: 100/100. Step 40/100. Loss: 6.22. Err: 7.19cm
# Epoch: 100/100. Step 41/100. Loss: 6.22. Err: 6.99cm
# Epoch: 100/100. Step 42/100. Loss: 6.22. Err: 6.95cm
# Epoch: 100/100. Step 43/100. Loss: 6.22. Err: 7.08cm
# Epoch: 100/100. Step 44/100. Loss: 6.22. Err: 7.02cm
# Epoch: 100/100. Step 45/100. Loss: 6.22. Err: 6.91cm
# Epoch: 100/100. Step 46/100. Loss: 6.22. Err: 6.96cm
# Epoch: 100/100. Step 47/100. Loss: 6.22. Err: 6.94cm
# Epoch: 100/100. Step 48/100. Loss: 6.22. Err: 7.11cm
# Epoch: 100/100. Step 49/100. Loss: 6.22. Err: 6.91cm
# Epoch: 100/100. Step 50/100. Loss: 6.22. Err: 7.13cm
# Epoch: 100/100. Step 51/100. Loss: 6.22. Err: 6.87cm
# Epoch: 100/100. Step 52/100. Loss: 6.22. Err: 7.04cm
# Epoch: 100/100. Step 53/100. Loss: 6.22. Err: 7.25cm
# Epoch: 100/100. Step 54/100. Loss: 6.22. Err: 6.91cm
# Epoch: 100/100. Step 55/100. Loss: 6.22. Err: 6.9cm
# Epoch: 100/100. Step 56/100. Loss: 6.22. Err: 7.23cm
# Epoch: 100/100. Step 57/100. Loss: 6.22. Err: 7.11cm
# Epoch: 100/100. Step 58/100. Loss: 6.22. Err: 6.9cm
# Epoch: 100/100. Step 59/100. Loss: 6.22. Err: 7.11cm
# Epoch: 100/100. Step 60/100. Loss: 6.22. Err: 7.3cm
# Epoch: 100/100. Step 61/100. Loss: 6.22. Err: 7.03cm
# Epoch: 100/100. Step 62/100. Loss: 6.22. Err: 6.81cm
# Epoch: 100/100. Step 63/100. Loss: 6.22. Err: 6.84cm
# Epoch: 100/100. Step 64/100. Loss: 6.22. Err: 6.8cm
# Epoch: 100/100. Step 65/100. Loss: 6.22. Err: 6.73cm
# Epoch: 100/100. Step 66/100. Loss: 6.22. Err: 6.87cm
# Epoch: 100/100. Step 67/100. Loss: 6.22. Err: 6.74cm
# Epoch: 100/100. Step 68/100. Loss: 6.22. Err: 6.7cm
# Epoch: 100/100. Step 69/100. Loss: 6.22. Err: 6.64cm
# Epoch: 100/100. Step 70/100. Loss: 6.22. Err: 6.68cm
# Epoch: 100/100. Step 71/100. Loss: 6.22. Err: 6.8cm
# Epoch: 100/100. Step 72/100. Loss: 6.22. Err: 6.91cm
# Epoch: 100/100. Step 73/100. Loss: 6.22. Err: 6.88cm
# Epoch: 100/100. Step 74/100. Loss: 6.22. Err: 6.83cm
# Epoch: 100/100. Step 75/100. Loss: 6.22. Err: 7.2cm
# Epoch: 100/100. Step 76/100. Loss: 6.22. Err: 6.65cm
# Epoch: 100/100. Step 77/100. Loss: 6.22. Err: 7.29cm
# Epoch: 100/100. Step 78/100. Loss: 6.22. Err: 7.27cm
# Epoch: 100/100. Step 79/100. Loss: 6.22. Err: 6.96cm
# Epoch: 100/100. Step 80/100. Loss: 6.23. Err: 8.63cm
# Epoch: 100/100. Step 81/100. Loss: 6.22. Err: 6.77cm
# Epoch: 100/100. Step 82/100. Loss: 6.22. Err: 8.05cm
# Epoch: 100/100. Step 83/100. Loss: 6.22. Err: 6.84cm
# Epoch: 100/100. Step 84/100. Loss: 6.23. Err: 8.5cm
# Epoch: 100/100. Step 85/100. Loss: 6.22. Err: 7.21cm
# Epoch: 100/100. Step 86/100. Loss: 6.22. Err: 7.89cm
# Epoch: 100/100. Step 87/100. Loss: 6.22. Err: 6.79cm
# Epoch: 100/100. Step 88/100. Loss: 6.22. Err: 7.86cm
# Epoch: 100/100. Step 89/100. Loss: 6.22. Err: 6.7cm
# Epoch: 100/100. Step 90/100. Loss: 6.22. Err: 7.99cm
# Epoch: 100/100. Step 91/100. Loss: 6.22. Err: 6.86cm
# Epoch: 100/100. Step 92/100. Loss: 6.22. Err: 7.72cm
# Epoch: 100/100. Step 93/100. Loss: 6.22. Err: 6.78cm
# Epoch: 100/100. Step 94/100. Loss: 6.22. Err: 7.51cm
# Epoch: 100/100. Step 95/100. Loss: 6.22. Err: 6.59cm
# Epoch: 100/100. Step 96/100. Loss: 6.22. Err: 7.67cm
# Epoch: 100/100. Step 97/100. Loss: 6.22. Err: 6.7cm
# Epoch: 100/100. Step 98/100. Loss: 6.22. Err: 7.46cm
# Epoch: 100/100. Step 99/100. Loss: 6.22. Err: 6.56cm

# %% [markdown]
# ## Evaluate performance

# %%
inputs, pos, pc_outputs = trajectory_generator.get_test_batch()
pos = pos.cpu()
pred_pos = place_cells.get_nearest_cell_pos(model.predict(inputs)).cpu()
us = place_cells.us.cpu()

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
for i in range(5):
    plt.plot(pos[:,i,0], pos[:,i,1], c='black', label='True position', linewidth=2)
    plt.plot(pred_pos[:,i,0], pred_pos[:,i,1], '.-',
             c='C1', label='Decoded position')
    if i==0:
        plt.legend()
plt.scatter(us[:,0], us[:,1], s=20, alpha=0.5, c='lightgrey')
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)
plt.xticks([])
plt.yticks([])
plt.xlim([-options.box_width/2,options.box_width/2])
plt.ylim([-options.box_height/2,options.box_height/2]);
# plt.savefig('images/sim_traj_decode.pdf')

# %%
# Visualize predicted place cell outputs
inputs, pos, pc_outputs = trajectory_generator.get_test_batch()
preds = model.predict(inputs)
preds = preds.reshape(-1, options.Np).detach().cpu()
pc_outputs = model.softmax(pc_outputs).reshape(-1, options.Np).cpu()
pc_pred = place_cells.grid_pc(preds[:100])
pc = place_cells.grid_pc(pc_outputs[:100])

plt.figure(figsize=(16,4))
for i in range(8):
    plt.subplot(2,8,i+9)
    plt.imshow(pc_pred[2*i], cmap='jet')
    if i==0:
        plt.ylabel('Predicted')
    plt.axis('off')
    
for i in range(8):
    plt.subplot(2,8,i+1)
    plt.imshow(pc[2*i], cmap='jet', interpolation='gaussian')
    if i==0:
        plt.ylabel('True')
    plt.axis('off')
    
plt.suptitle('Place cell outputs', fontsize=16)
plt.show()

# %% [markdown]
# # Ratemaps

# %%
from visualize import compute_ratemaps, plot_ratemaps
res = 50
n_avg = 100
Ng = options.Ng
activations, rate_map, g, pos = compute_ratemaps(model,
                                                 trajectory_generator,
                                                 options,
                                                 res=res,
                                                 n_avg=n_avg,
                                                 Ng=Ng)

# Compute a set of lo-res maps to use for evalutaing grid score
lo_res = 20
_, rate_map_lores, _, _ = compute_ratemaps(model,
                                         trajectory_generator,
                                         options,
                                         res=lo_res,
                                         n_avg=n_avg,
                                         Ng=Ng)
n_plot = 256
plt.figure(figsize=(16,4*n_plot//8**2))
rm_fig = plot_ratemaps(activations, n_plot, smooth=True)
plt.imshow(rm_fig)
plt.axis('off');

# %% [markdown]
# ## Grid scores

# %%
from scores import GridScorer

starts = [0.2] * 10
ends = np.linspace(0.4, 1.0, num=10)
box_width=options.box_width
box_height=options.box_height
coord_range=((-box_width/2, box_width/2), (-box_height/2, box_height/2))
masks_parameters = zip(starts, ends.tolist())
scorer = GridScorer(res, coord_range, masks_parameters)

score_60, score_90, max_60_mask, max_90_mask, sac, max_60_ind = zip(
      *[scorer.get_scores(rm.reshape(res, res)) for rm in tqdm(rate_map_lores)])

# %%
idxs = np.flip(np.argsort(score_60))
Ng = options.Ng

# Plot high grid scores
n_plot = 128
plt.figure(figsize=(16,4*n_plot//8**2))
rm_fig = plot_ratemaps(activations[idxs], n_plot, smooth=True)
plt.imshow(rm_fig)
plt.suptitle('Grid scores '+str(np.round(score_60[idxs[0]], 2))
             +' -- '+ str(np.round(score_60[idxs[n_plot]], 2)),
            fontsize=16)
plt.axis('off');

# Plot medium grid scores
plt.figure(figsize=(16,4*n_plot//8**2))
rm_fig = plot_ratemaps(activations[idxs[Ng//4:]], n_plot, smooth=True)
plt.imshow(rm_fig)
plt.suptitle('Grid scores '+str(np.round(score_60[idxs[Ng//2]], 2))
             +' -- ' + str(np.round(score_60[idxs[Ng//2+n_plot]], 2)),
            fontsize=16)
plt.axis('off');

# Plot low grid scores
plt.figure(figsize=(16,4*n_plot//8**2))
rm_fig = plot_ratemaps(activations[np.flip(idxs)], n_plot, smooth=True)
plt.imshow(rm_fig)
plt.suptitle('Grid scores '+str(np.round(score_60[idxs[-n_plot]], 2))
             +' -- ' + str(np.round(score_60[idxs[-1]], 2)),
            fontsize=16)
plt.axis('off');

# %%
plt.hist(score_60, range=(-1,2.5), bins=15);
plt.xlabel('Grid score')
plt.ylabel('Count');

# %% [markdown]
# # Manifold distance

# %%
# Keeping all grid cells
origins = np.stack(np.mgrid[:3,:3] - 1) * res//4 + res//2

fig = plt.figure(figsize=(8,8))
for i in range(3):
    for j in range(3):
        plt.subplot(3,3,3*i+j+1)
        origin=np.random.randint(0,100,2)
        origin_idx = np.ravel_multi_index((origins[0,i,j],origins[1,i,j]), (res,res))
        r0 = rate_map[:,origin_idx,None]
        dists = np.linalg.norm(r0 - rate_map, axis=0)
        im = plt.imshow(dists.reshape(res,res)/np.max(dists),
                        cmap='viridis_r', interpolation='gaussian')
        plt.axis('off')
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.12, 0.02, 0.74])
cbar = fig.colorbar(im, cax=cbar_ax)
cbar.ax.locator_params(nbins=3)
cbar.ax.tick_params(labelsize=20) 
cbar.outline.set_visible(False)

# %%
# Keeping only top 500 grid cells
n_grid_cells = 500
grid_sort = np.flip(np.argsort(score_60))
origins = np.stack(np.mgrid[:3,:3] - 1) * res//4 + res//2

fig = plt.figure(figsize=(8,8))
for i in range(3):
    for j in range(3):
        plt.subplot(3,3,3*i+j+1)
        origin=np.random.randint(0,100,2)
        origin_idx = np.ravel_multi_index((origins[0,i,j],origins[1,i,j]), (res,res))
        r0 = rate_map[grid_sort[:n_grid_cells],origin_idx,None]
        dists = np.linalg.norm(r0 - rate_map[grid_sort[:n_grid_cells]], axis=0)
        im = plt.imshow(dists.reshape(res,res)/np.max(dists),
                        cmap='viridis_r', interpolation='gaussian')
        plt.axis('off')
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.12, 0.02, 0.74])
cbar = fig.colorbar(im, cax=cbar_ax)
cbar.ax.locator_params(nbins=3)
cbar.ax.tick_params(labelsize=20) 
cbar.outline.set_visible(False)

# %% [markdown]
# # Neural sheet

# %%
# Fourier transform 
Ng = options.Ng
rm_fft_real = np.zeros([Ng,res,res])
rm_fft_imag = np.zeros([Ng,res,res])

for i in tqdm(range(Ng)):
    rm_fft_real[i] = np.real(np.fft.fft2(rate_map[i].reshape([res,res])))
    rm_fft_imag[i] = np.imag(np.fft.fft2(rate_map[i].reshape([res,res])))
    
rm_fft = rm_fft_real + 1j * rm_fft_imag

# %%
width = 6
idxs = np.arange(-width+1, width)
x2, y2 = np.meshgrid(np.arange(2*width-1), np.arange(2*width-1))
im = (np.real(rm_fft)**2).mean(0)
im[0,0] = 0
plt.scatter(x2,y2,c=im[idxs][:,idxs], s=300, cmap='Oranges')
plt.axis('equal')
plt.axis('off');
plt.title('Mean power');

# %%
k1 = [3,0]
k2 = [2,3]
k3 = [-1,3]
k4=k5=k6=k1

freq = 1
ks = freq*np.array([k1,k2,k3,k4,k5,k6])
ks = ks.astype('int')

modes = np.stack([rm_fft[:,k[0],k[1]] for k in ks])

# %%
# Find phases
phases = [np.angle(mode) for mode in modes]

plt.figure(figsize=(15,5))
plt.subplot(131)
plt.scatter(phases[0], phases[1], c='black', s=10)
plt.xlabel(r'$\phi_1$')
plt.ylabel(r'$\phi_2$')
plt.subplot(132)
plt.scatter(phases[1], phases[2], c='black', s=10)
plt.xlabel(r'$\phi_2$')
plt.ylabel(r'$\phi_3$')
plt.subplot(133)
plt.scatter(phases[0], phases[2], c='black', s=10)
plt.xlabel(r'$\phi_1$')
plt.ylabel(r'$\phi_3$')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(phases[0], phases[1], phases[2], c='black', s=2)
ax.view_init(azim=60)
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.xaxis._axinfo["grid"]['color'] =  (1,1,1,0)
ax.yaxis._axinfo["grid"]['color'] =  (1,1,1,0)
ax.zaxis._axinfo["grid"]['color'] =  (1,1,1,0)
ax.set_xlabel(r'$\phi_1$')
ax.set_ylabel(r'$\phi_2$')
ax.set_zlabel(r'$\phi_3$')

# %%
freq = 1
crop = 0
cmaps = ['Blues', 'Oranges', 'Greens']
x = np.mgrid[:res,:res] * 2*np.pi/ res
x = x.reshape(2, -1)
k = freq*np.stack([k1,k2,k3])
X = np.concatenate([np.cos(k.dot(x)), np.sin(k.dot(x))], axis=0)
idxs1, idxs2 = np.mgrid[crop:res-crop, crop:res-crop]
idxs = np.ravel_multi_index((idxs1,idxs2), (res,res)).ravel()

plt.figure(figsize=(12,4))
for i in range(3):
    plt.subplot(1,3,i+1)
    B = np.stack([np.cos(phases[i]), np.sin(phases[i])])
    test = B@rate_map
    plt.scatter(test[0], test[1], c=X[i][idxs], cmap=cmaps[i], s=20)
    plt.axis('off')

# %%
from utils import get_2d_sort
import scipy

# %%
N = rate_map.shape[0]
n = int(np.sqrt(N))
width = int(np.sqrt(N))
freq = 1
X,Y = np.meshgrid(np.arange(width),np.arange(width))
X = X*2*np.pi/width
Y = Y*2*np.pi/width

s1 = np.zeros(phases[0].shape)
s2 = np.zeros(phases[0].shape)

fac = np.sqrt(3)/2

for i in range(Ng):
    penalty_1 = np.cos(freq*X - phases[0][i]/fac)
    penalty_2 = np.cos(freq*Y - phases[2][i]/fac)
    penalty_3 = np.cos(freq*(X+Y) - phases[1][i]/fac)
    ind = np.argmax(penalty_1+penalty_2 + penalty_3  + np.random.randn()/100)
    s1[i],s2[i] = np.unravel_index([ind],penalty_1.shape)
    
total_order = get_2d_sort(s1,s2)
rm_sort_square = rate_map[total_order.ravel()].reshape([n,n,-1])

# %%
# Skew matrix to transform parallelogram unit cells to squares
A = np.asarray([[2,1],[0, np.sqrt(3)]])/4
Ainv = np.linalg.inv(A)

freq = 2
nplots=10
fig, axes = plt.subplots(nplots,nplots, figsize=(16,16))
for i in range(nplots):
    for j in range(nplots):
        idx = np.ravel_multi_index(((i+nplots//2)*res//nplots//freq,
                                    (j+nplots//2)*res//nplots//freq), (res,res))
        im = rm_sort_square[:,:,idx]
        im = scipy.ndimage.affine_transform(im, Ainv, mode='wrap')
        im = scipy.ndimage.gaussian_filter(im, sigma=(2,2))
        axes[j,i].imshow(im.T, cmap='jet')
        axes[j,i].axis('off')

# %% [markdown]
# # Connectivity

# %%
J = model.RNN.weights[1].numpy().T
plt.figure(figsize=(6,6))
plt.imshow(J, cmap='RdBu');
plt.title('J');

# %%
# Eigenvalues
eigs, eigvs = np.linalg.eig(J)

fig, ax = plt.subplots()
plt.scatter(np.real(eigs), np.imag(eigs), c='black', s=20)
plt.scatter(np.real(eigs[:9]), np.imag(eigs[:9]), c='C1', s=20)
circle1 = plt.Circle((0, 0), 1, color='tan',
                     fill=False, linestyle='dashed', linewidth=2)
ax.add_artist(circle1)
plt.xlim([-1.1,2.5])
plt.ylim([-1.1,1.1])
plt.gca().set_aspect('equal', adjustable='box')
plt.locator_params(nbins=4)
# plt.axis('equal')
# sns.despine()
# plt.savefig('images/final_eigs.pdf')

# %%
U,S,V = np.linalg.svd(J)

plt.figure(figsize=(8,4))
plt.plot(S[:100], 'o-', c='black')
plt.plot(S[:9], 'o-', c='C1')
# sns.despine();

# %%
A = np.asarray([[2,1],[0, np.sqrt(3)]])/2
Ainv = np.linalg.inv(A)

plt.figure(figsize=(12,8))
idxs = [1,3,5,4,0,2]
for i in range(6):
    plt.subplot(2,3,i+1)
    im = eigvs_rot[idxs[i]].reshape(n,n)
    im = np.roll(np.roll(im, n//4, axis=1), -n//4, axis=0)
    im = scipy.ndimage.affine_transform(im, Ainv, mode='wrap')
    if i==1 or i==4:
        im = np.roll(im, -n//3, axis=0)
    im = scipy.ndimage.gaussian_filter(im, sigma=(2,2))
    
    plt.imshow(im, cmap='coolwarm')
    plt.axis('off')
plt.tight_layout()
# plt.savefig('images/eigvs2.pdf')

# %%
idxs = np.flip(np.argsort(eigs))

A = np.asarray([[2,1],[0, np.sqrt(3)]])/2
Ainv = np.linalg.inv(A)

n = int(np.sqrt(Ng))
plt.figure(figsize=(16,4))
for i in range(24):
    plt.subplot(2,12,i+1)
    idx = idxs[i]
    im = np.real(eigvs[total_order,idx].reshape(n,n))
    im = scipy.ndimage.affine_transform(im, Ainv, mode='wrap')
    im = scipy.ndimage.gaussian_filter(im, sigma=(2,2)) 
    plt.imshow(im, cmap='coolwarm', interpolation='gaussian')
    plt.axis('off')

# %% [markdown]
# ## Sort weights

# %%
n = int(np.sqrt(Ng))
Jsort = J[total_order][:, total_order]
J_square = np.reshape(Jsort, (n,n,n,n))

Jmean = np.zeros([n,n])
for i in range(n):
    for j in range(n):
        Jmean += np.roll(np.roll(J_square[i,j], -i, axis=0), -j, axis=1)
        
Jmean[0,0] = np.max(Jmean[1:,1:])
Jmean = np.roll(np.roll(Jmean, n//2, axis=0), n//2, axis=1)
# plt.imshow(Jmean, cmap='coolwarm', interpolation='gaussian')

A = np.asarray([[2,1],[0, np.sqrt(3)]])/2
Ainv = np.linalg.inv(A)
im = Jmean
im = scipy.ndimage.affine_transform(Jmean, Ainv, mode='wrap')

imroll = im
imroll = np.roll(np.roll(im, -n//4, axis=0), 0, axis=1)
# imroll = scipy.ndimage.gaussian_filter(imroll, sigma=(1,1))

plt.figure(figsize=(5,5))
plt.imshow(imroll, cmap='coolwarm')
plt.title('J (sorted)')
plt.axis('off');
# plt.savefig('images/rnn_connectivity_sheared.pdf')

# %%
n = int(np.sqrt(N))
width = 18
xs = np.arange(2*width-1)
X,Y = np.meshgrid(xs,xs)
XY = np.stack((X.ravel(),Y.ravel()),0)
T = np.array([[1,0.5],[0,np.sqrt(3)/2]])
XY = T.dot(XY)#+ np.random.randn(*XY.shape)/100 

idxs = np.arange(-width+1, width)
im_fft = np.abs(np.fft.fft2(im))
im_fft[0,0] = 0

plt.figure(figsize=(10,10))
plt.scatter(XY[0],XY[1],s=120,c=im_fft[idxs][:,idxs].ravel(),
            marker='h', cmap='viridis')
plt.axis('equal')
plt.axis('off');
# plt.savefig('images/fft2.pdf')

# %% [markdown]
# # Path integration

# %%
# Compute JGv
J = model.RNN.weights[1].numpy().T
M = model.RNN.weights[0].numpy().T

theta = 0
v = np.stack([np.cos(theta), np.sin(theta)])

G = (J@rate_map) > 0
# G = rate_map > 0
Mv = M@v
GMv = G*Mv[:,None]
JGMv = J@GMv

# Compute sliding mode
shift = 5
SM = rate_map.reshape(Ng,res,res)
SM = np.roll(SM,shift=-shift,axis=1) - np.roll(SM,shift=shift,axis=1)
SM = SM.reshape(Ng, -1)

# Compute projection and cos ang
proj = tf.reduce_sum(JGMv * SM, axis=0)
cos_ang = proj / np.sqrt((np.sum(SM**2, axis=0) * np.sum(JGMv**2, axis=0)))

# %%
plt.rcParams.update({'font.size': 20})

crop = 10
idxs1, idxs2 = np.mgrid[crop:res-crop, crop:res-crop]
idxs = np.ravel_multi_index((idxs1,idxs2), (res,res)).ravel()
plt.figure(figsize=(8,5))
plt.hist(cos_ang.numpy()[idxs], bins=20, color='slategrey')
plt.xlim([0,0.8]);
# plt.locator_params(nbins=5)
plt.xlabel('Projection onto sliding mode')
plt.ylabel('Count')
# plt.title(r"$\frac{J\sigma'M \cdot \vec s}{\||J\sigma'M\||\ \||\vec s\||}$", fontsize=20);
# plt.savefig(folder+str('JGv.png'), dpi=1000)

# %%
thetas = np.linspace(0,2*np.pi,8, endpoint=False)
clock_idxs = np.roll([0,1,2,5,8,7,6,3], 1)
idx = np.ravel_multi_index((20,20), (res,res))

plt.figure(figsize=(9,9))
for i in range(8):
    theta = thetas[i]
    
    # Get JGMv
    v = np.stack([np.cos(theta), np.sin(theta)])
    Mv = M@v
    GMv = G[:,idx]*Mv
    JGMv = J@GMv
    
    #Plot
    plt.subplot(3,3,clock_idxs[i]+1)
    
    im = JGMv[total_order].reshape(n,n)
    im = scipy.ndimage.gaussian_filter(im, (3,3))
    plt.imshow(im, cmap='RdBu')
    plt.axis('off')
plt.tight_layout()

# %% [markdown]
# # SVD

# %%
# Perform SVD
import scipy
X = rate_map - rate_map.mean(-1,keepdims=True)
X -= X.mean(-1, keepdims=True)
Ua, S, V = scipy.linalg.svd(X)

rm_embed = Ua.T@rate_map

# %%
# Construct torus
# k1 = [1,0]
# k2 = [0.5, 0.5*np.sqrt(3)]
# k3 = np.array([-0.5, 0.5*np.sqrt(3)]) 

k1 = [3,0]
k2 = [2,2.5]
k3 = [-1,2.3]

# k1 = [1,0]
# k2 = [2,2.5]
# k3 = [-1,2.3]

freq = 1
x = np.mgrid[:res,:res] * 2*np.pi/ res
x = x.reshape(2, -1)
k = freq*np.stack([k1,k2,k3])
X = np.concatenate([np.cos(k.dot(x)), np.sin(k.dot(x))], axis=0)
cmaps = ['Blues', 'Oranges', 'Greens']

crop = 0
idxs1, idxs2 = np.mgrid[crop:res-crop, crop:res-crop]
idxs = np.ravel_multi_index((idxs1,idxs2), (res,res)).ravel()

# Find rotation
RM = rm_embed[:10, idxs]
X_crop = X[:,idxs]
R = np.linalg.inv(RM.dot(RM.T)).dot(RM).dot(X_crop.T).T

# Lowdin symmetric orthogonalization 
U,s,V = np.linalg.svd(R)
S2 = U.dot(np.diag(1./s)).dot(U.T)
R = S2.dot(R)

# Plot rings
plt.figure(figsize=(12,4))
for i in range(R.shape[0]//2):
    plt.subplot(1,3,i+1)
    plt.scatter(R.dot(RM)[i], R.dot(RM)[i+3], c=X[i][idxs], cmap=cmaps[i], s=10)
    plt.axis('off')
    
# plt.savefig(folder + 'ring_fit.png')

# %% [markdown]
# # Null model (low-pass filtered noise)

# %%
# res = 50
# coords = np.arange(resolution)*2*np.pi/res
# x, y = np.meshgrid(coords, coords)
# x = x.ravel(); y = y.ravel()
# k1, k2 = np.meshgrid(np.arange(-3,4),np.arange(-3,4))
# grid = k1[..., None]*x + k2[..., None]*y

# X = np.cos(grid)
# Y = np.sin(grid)
# H = np.stack([X, Y], axis=0).reshape(-1, (resolution)**2)

# Ng = 100
# pattern = np.random.randn(Ng,98).dot(H)

# %%
# Construct filter
max_freq = 3
min_freq = 0
x, y = np.meshgrid(np.arange(res), np.arange(res))
r = np.sqrt((x-res//2)**2 + (y-res//2)**2)
filt = np.greater(max_freq - r, 0) * np.greater(r-min_freq,0)
# sigma = 5
# filt = np.exp(-r**2/2/sigma) * filt1

# Make random noise patterns
N = 4096
noise = np.random.randn(N, res, res)

# Convolve with filter
noise_tilde = np.fft.fftshift(np.fft.fft2(noise))
noise_tilde_filt = noise_tilde * filt
patterns = np.real(np.fft.ifft2(np.fft.ifftshift(noise_tilde_filt)))

# %%
# Fourier transform 
rm_fft_real = np.zeros([N,res,res])
rm_fft_imag = np.zeros([N,res,res])

for i in tqdm(range(N)):
    rm_fft_real[i] = np.real(np.fft.fft2(patterns[i].reshape([res,res])))
    rm_fft_imag[i] = np.imag(np.fft.fft2(patterns[i].reshape([res,res])))
    
rm_fft = rm_fft_real + 1j * rm_fft_imag

# %%
k1 = [3,0]
k2 = [2,3]
k3 = [-1,3]
k4=k5=k6=k1

freq = 1
ks = freq*np.array([k1,k2,k3,k4,k5,k6])
ks = ks.astype('int')

modes = np.stack([rm_fft[:,k[0],k[1]] for k in ks])
# Find phases
phases = [np.angle(mode) for mode in modes]

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(phases[0], phases[1], phases[2], c='black', s=10)
ax.view_init(azim=60)
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.xaxis._axinfo["grid"]['color'] =  (1,1,1,0)
ax.yaxis._axinfo["grid"]['color'] =  (1,1,1,0)
ax.zaxis._axinfo["grid"]['color'] =  (1,1,1,0)
ax.set_xlabel(r'$\phi_1$')
ax.set_ylabel(r'$\phi_2$')
ax.set_zlabel(r'$\phi_3$')
plt.title('Null model does not obey phase relationship');

# %%
crop = 0
freq = 1
x = np.mgrid[:res,:res] * 2*np.pi/ res
x = x.reshape(2, -1)
k = freq*np.stack([k1,k2,k3])
X = np.concatenate([np.cos(k.dot(x)), np.sin(k.dot(x))], axis=0)
idxs1, idxs2 = np.mgrid[crop:res-crop, crop:res-crop]
idxs = np.ravel_multi_index((idxs1,idxs2), (res,res)).ravel()

plt.figure(figsize=(12,4))
for i in range(3):
    plt.subplot(1,3,i+1)
    B = np.stack([np.cos(phases[i]), np.sin(phases[i])])
    test = B@patterns.reshape(N,-1)
    plt.scatter(test[0], test[1], c=X[i][idxs], cmap=cmaps[i], s=20)
    plt.axis('off')

# %% [markdown]
# # Boundary extension

# %%
options.sequence_length = 80
options.box_width = 4.4
options.box_height = 4.4
trajectory_generator = TrajectoryGenerator(options, place_cells)

# %%
from visualize import compute_ratemaps, plot_ratemaps
res = 50
n_avg = 10
Ng = options.Ng
activations, rate_map, g, pos = compute_ratemaps(model,
                                                 trajectory_generator,
                                                 options,
                                                 res=res,
                                                 n_avg=n_avg,
                                                 Ng=Ng)

n_plot = 256
plt.figure(figsize=(16,4*n_plot//8**2))
rm_fig = plot_ratemaps(activations, n_plot, smooth=True)
plt.imshow(rm_fig)
plt.axis('off');

# %% [markdown]
# # Head direction and speed tuning

# %%
g = []
vs = []
hds = []
navg = 100
for index in tqdm(range(n_avg), leave=False, desc='Computing ratemaps'):
    inputs, pos_batch, _ = trajectory_generator.get_test_batch()
    v = inputs[0].cpu().numpy()
    g_batch = model.g(inputs).detach().cpu().numpy()

    vx,vy = v[:,:,0], v[:,:,1]
    v = np.sqrt(vx**2 + vy**2)
    hd = np.arctan2(vy,vx)
    g_batch = np.reshape(g_batch, (-1,Ng))

    g.append(g_batch)
    vs.append(v.ravel())
    hds.append(hd)

g = np.stack(g).reshape([-1, Ng])
vs = np.stack(vs).ravel()
hds = np.stack(hds).ravel()

# %%
# Construct speed tuning curves
speed_curves = []
speed_scores = []
for i in tqdm(range(Ng)):
    stat,bins,_ = scipy.stats.binned_statistic(vs,g[:,i], bins=10, range=(0,0.05))
    speed_curves.append(stat)
    speed_scores.append(np.corrcoef(vs, g[:,i])[0,1])
speed_curves = np.stack(speed_curves)

# %%
# Plot a sampling of tuning curves in 2d PCA space
nplot = 10
U,S,V = np.linalg.svd(speed_curves - speed_curves.mean(-1,keepdims=True))
x = -U[:,1]
y = -U[:,0]
x = (x+np.abs(x.min))
x = nplot*x/x.max()
y = (y+np.abs(y.min))
y = nplot*y/y.max()
# x = nplot*(scipy.special.erf((x-x.mean())/x.std())+1)/2
# y = nplot*(scipy.special.erf((y-y.mean())/y.std())+1)/2

plt.figure(figsize=(8,8))
for i in range(nplot):
    for j in range(nplot):
        plt.subplot(nplot,nplot,i*nplot+j+1)
        candidates = (x>i)*(x<i+1)*(y>j)*(y<j+1)
        idxs = np.arange(Ng)[candidates]
        try:
            plt.plot(speed_curves[np.random.choice(idxs)], c='black', linewidth=2)
        except:
            pass
        plt.axis('off')
plt.suptitle('Speed', y=0.92)
# plt.savefig('images/speed_tuning_pca.pdf')

# %%
# Construct head direction tuning curves
hd_curves = []
hd_scores = []
for i in tqdm(range(Ng)):
    stat,bins,_ = scipy.stats.binned_statistic(hds,g[:,i], bins=10, range=(-np.pi,np.pi))
    hd_curves.append(stat)
    hd_scores.append(np.corrcoef(hds, g[:,i])[0,1])
hd_curves = np.stack(hd_curves)

# %%
# Plot a sampling of tuning curves in 2d PCA space
nplot = 10
U,S,V = np.linalg.svd(hd_curves - hd_curves.mean(-1,keepdims=True))
x = -U[:,1]
y = -U[:,0]
x = nplot*(scipy.special.erf((x-x.mean())/x.std())+1)/2
y = nplot*(scipy.special.erf((y-y.mean())/y.std())+1)/2

plt.figure(figsize=(8,8))
for i in range(nplot):
    for j in range(nplot):
        plt.subplot(nplot,nplot,i*nplot+j+1)
        candidates = (x>i)*(x<i+1)*(y>j)*(y<j+1)
        idxs = np.arange(Ng)[candidates]
        try:
            plt.plot(hd_curves[np.random.choice(idxs)], c='black', linewidth=2)
        except:
            pass
        plt.axis('off')
plt.suptitle('Head direction', y=0.92)
# plt.savefig('images/hd_tuning_pca.pdf')

# %%
# Plot position tuning curves in 2d space

# %%
U,S,V = np.linalg.svd(rate_map - rate_map.mean(-1,keepdims=True))

# %%
import seaborn as sns
sns.set(font_scale=1.2, style='ticks')

# %%
plt.plot(S[:20], 'o-')

# %%
idxs = np.where(border_scores>0.6)[0]

plt.figure(figsize=(10,10))
for i,idx in enumerate(idxs):
    plt.subplot(10,11,i+1)
    plt.imshow(rate_map[idx].reshape(res,res), cmap='jet')
    plt.axis('off')

# %%
plt.figure(figsize=(4,4))
counter = 0
plt.figure(figsize=(8,8))
for i in range(6):
    for j in range(i+1,6):
        counter+=1
        plt.subplot(4,4,counter)
        x = U[:,i]
        x = (x-x.mean())/x.std()
        y = U[:,j]
        y = (y-y.mean())/y.std()

        # n = (score_60<0.3).sum()
        # idxs = np.random.choice(np.arange(n), 523)
        plt.scatter(x[grid_sort[score_60<1]], y[grid_sort[score_60<1]], c='grey')
        plt.scatter(x[grid_sort[score_60>1]], y[grid_sort[score_60>1]], c='black')
        plt.scatter(x[grid_sort[border_scores>0.6]], y[grid_sort[border_scores>0.6]], c='tan')
        plt.axis('equal')
        plt.xlim([-6,6])
        plt.ylim([-6,6])
        sns.despine();

# %%
nplot = 20
x = U[:,2]
y = U[:,1]
x = nplot*(x+0.1)/0.2
y = nplot*(y+0.1)/0.2
# x = x + np.abs(x.min())
# x = nplot*x/np.max(x)
# y = y + np.abs(y.min())
# y = nplot*y/np.max(y)
# x = nplot*(scipy.special.erf((x-x.mean())/x.std())+1)/2
# y = nplot*(scipy.special.erf((y-y.mean())/y.std())+1)/2

plt.figure(figsize=(8,8))
for i in range(nplot):
    for j in range(nplot):
        plt.subplot(nplot,nplot,i*nplot+j+1)
        candidates = (x>i)*(x<i+1)*(y>j)*(y<j+1)
        idxs = np.arange(Ng)[candidates]
        try:
            plt.imshow(rate_map[np.random.choice(idxs)].reshape(res,res),
                      cmap='jet')
        except:
            pass
        plt.axis('off')
# plt.savefig('images/rate_maps_pca.pdf')

# %%
nplot = 20
x = U[:,0]
y = U[:,1]
x = nplot*(scipy.special.erf((x-x.mean())/x.std())+1)/2
y = nplot*(scipy.special.erf((y-y.mean())/y.std())+1)/2

plt.figure(figsize=(8,8))
for i in range(nplot):
    for j in range(nplot):
        plt.subplot(nplot,nplot,i*nplot+j+1)
        candidates = (x>i)*(x<i+1)*(y>j)*(y<j+1)
        idxs = np.arange(Ng)[candidates]
        try:
            plt.imshow(rate_map[np.random.choice(idxs)].reshape(res,res),
                      cmap='jet')
        except:
            pass
        plt.axis('off')
# plt.savefig('images/rate_maps_pca.pdf')

# %% [markdown]
# # Border score

# %%
from scores import border_score

# %%
border_scores = []
cms = []
dms = []
for i in tqdm(range(Ng)):
    rm = rate_map[i].reshape(res,res)
    bscore, cm, dm = border_score(rm, res, options.box_width)
    border_scores.append(bscore)
    cms.append(cm)
    dms.append(dm)
border_scores = np.stack(border_scores)

# %%
plt.hist(dms)

# %%
border_sort = np.argsort(np.nan_to_num(border_scores))
plt.figure(figsize=(8,16))
for i in range(200):
    plt.subplot(20,10,i+1)
    plt.imshow(rate_map[border_sort[-1-i]].reshape(res,res), cmap='jet')
    plt.axis('off')

# %%
border_sort = np.argsort(np.nan_to_num(border_scores))
plt.figure(figsize=(8,8))
for i in range(100):
    plt.subplot(10,10,i+1)
    plt.imshow(rate_map[border_sort[-1-i]].reshape(res,res), cmap='jet')
    plt.axis('off')

# %%
rm = rate_map[border_sort[-4]].reshape(res,res)

# Keep fields with area > 200cm^2
masks = []
nfields = 0
for i in range(1,ncomps+1):
    mask = (rm_comps==i).reshape(res,res)
    if mask.sum()*pix_area > 800:
        masks.append(mask)
        nfields += 1
